# %%
import random

# %%
sample_list_1=[]

for i in range(80):
    sample_list_1.append(random.randint(0,100))
    print(sample_list_1)
# Out:
# [62]
# [62, 11]
# [62, 11, 61]
# [62, 11, 61, 60]
# [62, 11, 61, 60, 73]
# [62, 11, 61, 60, 73, 4]
# [62, 11, 61, 60, 73, 4, 42]
# [62, 11, 61, 60, 73, 4, 42, 48]
# [62, 11, 61, 60, 73, 4, 42, 48, 11]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21, 22]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21, 22, 88]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21, 22, 88, 30]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21, 22, 88, 30, 54]
# [62, 11, 61, 60, 73, 4, 42, 48, 11, 14, 1, 91, 16, 71, 86, 21, 22, 88, 30, 54, 20]
# ...
