# %%
# 1. Aggregate the data into one Data Frame using Pandas. 

    # 1.1 Importing the data frames using libraries 
    
import numpy as np
import pandas as pd
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
  # 1.2 Unify the columns names before concating them.

file1=file1.rename(columns={'ST':'State','GENDER':'Gender'})
file2=file2.rename(columns={'ST':'State','GENDER':'Gender'})
file3=file3.rename(columns={'ST':'State','GENDER':'Gender'})

# %%
# 1.3 Aggregate the data into one Data Frame using Pandas.
    
file4=pd.concat([file1,file2,file3], axis=0)

# %%
#2. Standardizing header names

def lower_case_column_names(file4):
       #list comprenhension 
    file4.columns=[header.lower() for header in file4.columns]
        
    return file4

file4=lower_case_column_names(file4)
file4
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# 3. Removing duplicates

file4.drop_duplicates()
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# 4. Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data

def drop_columns(file4):
    file4.drop(columns=['customer'], inplace=True)
    return file4

drop_columns(file4)
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
# 4. Working with data types – 
    # Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

file4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
#how to find the data type and quantity of data in a column.
print(file4['customer lifetime value'].apply(type).value_counts())
# Out:
# <class 'float'>    10014
# <class 'str'>       2060
# Name: customer lifetime value, dtype: int64

# %%
# 5. Remove the % of customer lifetime value

file4['customer lifetime value']=file4['customer lifetime value'].apply(lambda x: x.replace('%', '') if isinstance(x, str) else x)

# %%
# Showing that the symbol"%" is removed. 

file4
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
#Reset index in the data frame to avoid multiple "o" index

file4=file4.reset_index(drop=True)

# %%
file4['customer lifetime value'] = file4['customer lifetime value'].astype(float)

# %%
# Calculation of the mean to replace NAN with this value 

mean_clv = file4['customer lifetime value'].mean()
mean_clv
# Out:
# 182196.38968985566

# %%
# Replace NAN with the mean 
file4['customer lifetime value'] = file4['customer lifetime value'].fillna(mean_clv)

# %%
file4
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master             1.821964e+05
# 1         Arizona      F              Bachelor             6.979536e+05
# 2          Nevada      F              Bachelor             1.288743e+06
# 3      California      M              Bachelor             7.645862e+05
# 4      Washington      M  High School or Below             5.363077e+05
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             2.340599e+04
# 12070  California      F               College             3.096511e+03
# 12071  California      M              Bachelor             8.163890e+03
# 12072  California      M               College             7.524442e+03
# 12073  California      M               College             2.611837e+03
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
#rounding the number to decimals

file4['customer lifetime value'] = file4['customer lifetime value'].round(0)
file4
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                 182196.0
# 1         Arizona      F              Bachelor                 697954.0
# 2          Nevada      F              Bachelor                1288743.0
# 3      California      M              Bachelor                 764586.0
# 4      Washington      M  High School or Below                 536308.0
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor                  23406.0
# 12070  California      F               College                   3097.0
# 12071  California      M              Bachelor                   8164.0
# 12072  California      M               College                   7524.0
# 12073  California      M               College                   2612.0
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
#extract the middle number of 'number of open complaints' which is changing between records.

file4['number of open complaints']=file4['number of open complaints'].apply(lambda x: x.replace('%', '') if isinstance(x, str) else x)
