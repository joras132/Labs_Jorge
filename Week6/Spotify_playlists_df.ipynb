# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentials
import config
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
# Extracting json file from a playlsit 
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DWXx3Txis2L4x",market="GB")

# %%
type(playlist)
#it is a dict nested
# Out:
# dict

# %%
# Checking the structure of the json file
import pprint
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXx3Txis2L4x/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#                                              'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#                                              'id': '2qk9voo8llSGYcZ6xrBzKx',
#                                              'name': 'Kings of Leon',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#                                 'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#                                 'id': '5CZR6ljD0x9fTiS4mh9wMp',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Only By The Night',
#                                 'release_date': '2008-09-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#                                    'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#                                    'id': '2qk9voo8llSGYcZ6xrBzKx',
#                                    'name': 'Kings of Leon',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#                       'disc_number': 1,
#                       'duration_ms': 203346,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRC10800300'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5A1FmxbYVRZKy4nc16MAue'},
#                       'href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#                       'id': '5A1FmxbYVRZKy4nc16MAue',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#                                       'id': '0ntQJM78wzOLVeCUAW7Y45',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45'},
#                       'name': 'Sex on Fire',
#                       'popularity': 71,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': '#c97251',
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#                                              'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#                                              'id': '3Ayl7mCk0nScecqOzvNp6s',
#                                              'name': 'Jimmy Eat World',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0UJhhj5bn5AGAjryFnhueP'},
#                                 'href': 'https://api.spotify.com/v1/albums/0UJhhj5bn5AGAjryFnhueP',
#                                 'id': '0UJhhj5bn5AGAjryFnhueP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27395d1d98c5176e4f982bd73d6',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0295d1d98c5176e4f982bd73d6',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485195d1d98c5176e4f982bd73d6',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Bleed American',
#                                 'release_date': '2001-07-17',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0UJhhj5bn5AGAjryFnhueP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#                                    'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#                                    'id': '3Ayl7mCk0nScecqOzvNp6s',
#                                    'name': 'Jimmy Eat World',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'}],
#                       'disc_number': 1,
#                       'duration_ms': 165853,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USDW10110256'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6GG73Jik4jUlQCkKg9JuGO'},
#                       'href': 'https://api.spotify.com/v1/tracks/6GG73Jik4jUlQCkKg9JuGO',
#                       'id': '6GG73Jik4jUlQCkKg9JuGO',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'The Middle',
#                       'popularity': 82,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:6GG73Jik4jUlQCkKg9JuGO'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#                                              'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#                                              'id': '7Ln80lUS6He07XvHI8qqHH',
#                                              'name': 'Arctic Monkeys',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#                                 'href': 'https://api.spotify.com/v1/albums/78bpIziExqiI9qztvNFlQu',
#                                 'id': '78bpIziExqiI9qztvNFlQu',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734ae1c4c5c45aabe565499163',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514ae1c4c5c45aabe565499163',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'AM',
#                                 'release_date': '2013-09-09',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:78bpIziExqiI9qztvNFlQu'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#                                    'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#                                    'id': '7Ln80lUS6He07XvHI8qqHH',
#                                    'name': 'Arctic Monkeys',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#                       'disc_number': 1,
#                       'duration_ms': 207356,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBCEL1300365'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7nzsY8vlnKdvGOEE0rjAXZ'},
#                       'href': 'https://api.spotify.com/v1/tracks/7nzsY8vlnKdvGOEE0rjAXZ',
#                       'id': '7nzsY8vlnKdvGOEE0rjAXZ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Arabella',
#                       'popularity': 79,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/974bb8b08005bbc3c38a3b1389debf8e51fa1f20?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 4,
#                       'type': 'track',
#                       'uri': 'spotify:track:7nzsY8vlnKdvGOEE0rjAXZ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#                                              'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#                                              'id': '0epOFNiUfyON9EYx7Tpr6V',
#                                              'name': 'The Strokes',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3HFbH1loOUbqCyPsLuHLLh'},
#                                 'href': 'https://api.spotify.com/v1/albums/3HFbH1loOUbqCyPsLuHLLh',
#                                 'id': '3HFbH1loOUbqCyPsLuHLLh',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2730f35726025e0f025da4c688f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e020f35726025e0f025da4c688f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048510f35726025e0f025da4c688f',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Room On Fire',
#                                 'release_date': '2003-10-28',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3HFbH1loOUbqCyPsLuHLLh'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#                                    'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#                                    'id': '0epOFNiUfyON9EYx7Tpr6V',
#                                    'name': 'The Strokes',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#                       'disc_number': 1,
#                       'duration_ms': 219826,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRC10301519'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/57Xjny5yNzAcsxnusKmAfA'},
#                       'href': 'https://api.spotify.com/v1/tracks/57Xjny5yNzAcsxnusKmAfA',
#                       'id': '57Xjny5yNzAcsxnusKmAfA',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Reptilia',
#                       'popularity': 77,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/35521d82091e8c9a6a1cee80fb59dc2f6b5cb776?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:57Xjny5yNzAcsxnusKmAfA'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Ffb6ejR6Fe5IamqA5oRUF'},
#                                              'href': 'https://api.spotify.com/v1/artists/1Ffb6ejR6Fe5IamqA5oRUF',
#                                              'id': '1Ffb6ejR6Fe5IamqA5oRUF',
#                                              'name': 'Bring Me The Horizon',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7FqHuAvmREiIwVXVpZ9ooP'},
#                                 'href': 'https://api.spotify.com/v1/albums/7FqHuAvmREiIwVXVpZ9ooP',
#                                 'id': '7FqHuAvmREiIwVXVpZ9ooP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273736145b97bab8fa92cb6113f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02736145b97bab8fa92cb6113f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851736145b97bab8fa92cb6113f',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': "That's The Spirit",
#                                 'release_date': '2015-09-11',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7FqHuAvmREiIwVXVpZ9ooP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Ffb6ejR6Fe5IamqA5oRUF'},
#                                    'href': 'https://api.spotify.com/v1/artists/1Ffb6ejR6Fe5IamqA5oRUF',
#                                    'id': '1Ffb6ejR6Fe5IamqA5oRUF',
#                                    'name': 'Bring Me The Horizon',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF'}],
#                       'disc_number': 1,
#                       'duration_ms': 191520,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBARL1500770'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0M3adYbGtyRHACP86dey1H'},
#                       'href': 'https://api.spotify.com/v1/tracks/0M3adYbGtyRHACP86dey1H',
#                       'id': '0M3adYbGtyRHACP86dey1H',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Throne',
#                       'popularity': 76,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/b2da695e6b81068ff4a70c1416f4bd0c45e8d894?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:0M3adYbGtyRHACP86dey1H'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': '#e18a2e',
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#                                              'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#                                              'id': '2d0hyoQ5ynDBnkvAbJKORj',
#                                              'name': 'Rage Against The Machine',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/24E6rDvGDuYFjlGewp4ntF'},
#                                 'href': 'https://api.spotify.com/v1/albums/24E6rDvGDuYFjlGewp4ntF',
#                                 'id': '24E6rDvGDuYFjlGewp4ntF',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273053f006079bce979e5fef1e1',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02053f006079bce979e5fef1e1',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851053f006079bce979e5fef1e1',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Evil Empire',
#                                 'release_date': '1996-04-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:24E6rDvGDuYFjlGewp4ntF'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#                                    'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#                                    'id': '2d0hyoQ5ynDBnkvAbJKORj',
#                                    'name': 'Rage Against The Machine',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#                       'disc_number': 1,
#                       'duration_ms': 229466,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USSM19502563'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0tZ3mElWcr74OOhKEiNz1x'},
#                       'href': 'https://api.spotify.com/v1/tracks/0tZ3mElWcr74OOhKEiNz1x',
#                       'id': '0tZ3mElWcr74OOhKEiNz1x',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Bulls On Parade',
#                       'popularity': 76,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/c1626784be02379a8ec2fa5f7d7f735c1eda772b?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:0tZ3mElWcr74OOhKEiNz1x'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03r4iKL2g2442PT9n2UKsx'},
#                                              'href': 'https://api.spotify.com/v1/artists/03r4iKL2g2442PT9n2UKsx',
#                                              'id': '03r4iKL2g2442PT9n2UKsx',
#                                              'name': 'Beastie Boys',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:03r4iKL2g2442PT9n2UKsx'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6lfjbwFGzQ6aSNP1N3JlT8'},
#                                 'href': 'https://api.spotify.com/v1/albums/6lfjbwFGzQ6aSNP1N3JlT8',
#                                 'id': '6lfjbwFGzQ6aSNP1N3JlT8',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273436a305db8bd85b820da3e5a',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02436a305db8bd85b820da3e5a',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851436a305db8bd85b820da3e5a',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Ill Communication',
#                                 'release_date': '1994-05-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6lfjbwFGzQ6aSNP1N3JlT8'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03r4iKL2g2442PT9n2UKsx'},
#                                    'href': 'https://api.spotify.com/v1/artists/03r4iKL2g2442PT9n2UKsx',
#                                    'id': '03r4iKL2g2442PT9n2UKsx',
#                                    'name': 'Beastie Boys',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:03r4iKL2g2442PT9n2UKsx'}],
#                       'disc_number': 1,
#                       'duration_ms': 178440,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USCA29400020'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0Puj4YlTm6xNzDDADXHMI9'},
#                       'href': 'https://api.spotify.com/v1/tracks/0Puj4YlTm6xNzDDADXHMI9',
#                       'id': '0Puj4YlTm6xNzDDADXHMI9',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Sabotage',
#                       'popularity': 76,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 6,
#                       'type': 'track',
#                       'uri': 'spotify:track:0Puj4YlTm6xNzDDADXHMI9'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': '#948672',
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#                                              'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#                                              'id': '7mnBLXK823vNxN3UWB7Gfz',
#                                              'name': 'The Black Keys',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5DLhV9yOvZ7IxVmljMXtNm'},
#                                 'href': 'https://api.spotify.com/v1/albums/5DLhV9yOvZ7IxVmljMXtNm',
#                                 'id': '5DLhV9yOvZ7IxVmljMXtNm',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2736a21b97de47168df4f0c1993',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e026a21b97de47168df4f0c1993',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048516a21b97de47168df4f0c1993',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'El Camino',
#                                 'release_date': '2011-12-06',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5DLhV9yOvZ7IxVmljMXtNm'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#                                    'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#                                    'id': '7mnBLXK823vNxN3UWB7Gfz',
#                                    'name': 'The Black Keys',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#                       'disc_number': 1,
#                       'duration_ms': 193653,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USNO11100273'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5G1sTBGbZT5o4PNRc75RKI'},
#                       'href': 'https://api.spotify.com/v1/tracks/5G1sTBGbZT5o4PNRc75RKI',
#                       'id': '5G1sTBGbZT5o4PNRc75RKI',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Lonely Boy',
#                       'popularity': 76,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/cb384c17027f77dd419356db04186415edea2b90?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:5G1sTBGbZT5o4PNRc75RKI'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#                                              'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#                                              'id': '7jy3rLJdDQY21OgRLCZ9sD',
#                                              'name': 'Foo Fighters',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1zQ6F8gMagKcPL4SoA80cx'},
#                                 'href': 'https://api.spotify.com/v1/albums/1zQ6F8gMagKcPL4SoA80cx',
#                                 'id': '1zQ6F8gMagKcPL4SoA80cx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273b00ee453b3496535eaa6e4b3',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02b00ee453b3496535eaa6e4b3',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851b00ee453b3496535eaa6e4b3',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'One By One (Expanded Edition)',
#                                 'release_date': '2002-10-22',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1zQ6F8gMagKcPL4SoA80cx'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#                                    'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#                                    'id': '7jy3rLJdDQY21OgRLCZ9sD',
#                                    'name': 'Foo Fighters',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#                       'disc_number': 1,
#                       'duration_ms': 263440,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRW30200001'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6tsojOQ5wHaIjKqIryLZK6'},
#                       'href': 'https://api.spotify.com/v1/tracks/6tsojOQ5wHaIjKqIryLZK6',
#                       'id': '6tsojOQ5wHaIjKqIryLZK6',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'All My Life',
#                       'popularity': 75,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/f3cf56a45924d4cecd7ed50becfa51ec84a41e3c?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6tsojOQ5wHaIjKqIryLZK6'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YcBF2ttyueytpXtEzn1Za'},
#                                              'href': 'https://api.spotify.com/v1/artists/3YcBF2ttyueytpXtEzn1Za',
#                                              'id': '3YcBF2ttyueytpXtEzn1Za',
#                                              'name': 'Incubus',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3YcBF2ttyueytpXtEzn1Za'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1rQZbncicoXyB64DqoH7OY'},
#                                 'href': 'https://api.spotify.com/v1/albums/1rQZbncicoXyB64DqoH7OY',
#                                 'id': '1rQZbncicoXyB64DqoH7OY',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273289320ef78f164a472698926',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02289320ef78f164a472698926',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851289320ef78f164a472698926',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Morning View',
#                                 'release_date': '2001-10-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1rQZbncicoXyB64DqoH7OY'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YcBF2ttyueytpXtEzn1Za'},
#                                    'href': 'https://api.spotify.com/v1/artists/3YcBF2ttyueytpXtEzn1Za',
#                                    'id': '3YcBF2ttyueytpXtEzn1Za',
#                                    'name': 'Incubus',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3YcBF2ttyueytpXtEzn1Za'}],
#                       'disc_number': 1,
#                       'duration_ms': 212733,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM10107084'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6KtLECDztnah63TNmV4Plw'},
#                       'href': 'https://api.spotify.com/v1/tracks/6KtLECDztnah63TNmV4Plw',
#                       'id': '6KtLECDztnah63TNmV4Plw',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Wish You Were Here',
#                       'popularity': 72,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/3c423190127a2748aad13610df1d44a36f45c956?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:6KtLECDztnah63TNmV4Plw'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#                                              'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#                                              'id': '7bu3H8JO7d0UbMoVzbo70s',
#                                              'name': 'The Cure',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#                                 'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#                                 'id': '37Q22g0n9PzBLX6lNddrIa',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Kiss Me, Kiss Me, Kiss Me',
#                                 'release_date': '1987-05-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#                                    'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#                                    'id': '7bu3H8JO7d0UbMoVzbo70s',
#                                    'name': 'The Cure',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#                       'disc_number': 1,
#                       'duration_ms': 212013,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBALB8700003'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4NnWuGQujzWUEg0uZokO5M'},
#                       'href': 'https://api.spotify.com/v1/tracks/4NnWuGQujzWUEg0uZokO5M',
#                       'id': '4NnWuGQujzWUEg0uZokO5M',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#                                       'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#                                       'id': '76GlO5H5RT6g7y0gev86Nk',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#                       'name': 'Just Like Heaven',
#                       'popularity': 74,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 9,
#                       'type': 'track',
#                       'uri': 'spotify:track:4NnWuGQujzWUEg0uZokO5M'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': '#729c84',
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#                                              'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#                                              'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#                                              'name': 'My Chemical Romance',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2wPnKggTK3QhYAKL7Q0vvr'},
#                                 'href': 'https://api.spotify.com/v1/albums/2wPnKggTK3QhYAKL7Q0vvr',
#                                 'id': '2wPnKggTK3QhYAKL7Q0vvr',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2736fbf4bb780a9cbc34b3f35da',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e026fbf4bb780a9cbc34b3f35da',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048516fbf4bb780a9cbc34b3f35da',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Danger Days: The True Lives of the '
#                                         'Fabulous Killjoys',
#                                 'release_date': '2010-11-05',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2wPnKggTK3QhYAKL7Q0vvr'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#                                    'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#                                    'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#                                    'name': 'My Chemical Romance',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#                       'disc_number': 1,
#                       'duration_ms': 205960,
#                       'episode': False,
#                       'explicit': True,
# ...
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kNQXvepPjaPgUfeDAF2h6'},
#                                              'href': 'https://api.spotify.com/v1/artists/1kNQXvepPjaPgUfeDAF2h6',
#                                              'id': '1kNQXvepPjaPgUfeDAF2h6',
#                                              'name': 'You Me At Six',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1kNQXvepPjaPgUfeDAF2h6'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0S9IWlmYkM6ULSB1BExd5t'},
#                                 'href': 'https://api.spotify.com/v1/albums/0S9IWlmYkM6ULSB1BExd5t',
#                                 'id': '0S9IWlmYkM6ULSB1BExd5t',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273832f747b8b2d5c9a71f4a97f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02832f747b8b2d5c9a71f4a97f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851832f747b8b2d5c9a71f4a97f',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'SUCKAPUNCH',
#                                 'release_date': '2021-01-15',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0S9IWlmYkM6ULSB1BExd5t'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kNQXvepPjaPgUfeDAF2h6'},
#                                    'href': 'https://api.spotify.com/v1/artists/1kNQXvepPjaPgUfeDAF2h6',
#                                    'id': '1kNQXvepPjaPgUfeDAF2h6',
#                                    'name': 'You Me At Six',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1kNQXvepPjaPgUfeDAF2h6'}],
#                       'disc_number': 1,
#                       'duration_ms': 225786,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'GBKPL2018245'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3SevJWsbqUOpfPOpRZGrP9'},
#                       'href': 'https://api.spotify.com/v1/tracks/3SevJWsbqUOpfPOpRZGrP9',
#                       'id': '3SevJWsbqUOpfPOpRZGrP9',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Beautiful Way',
#                       'popularity': 53,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/a8e571d6fd57acd96b16bea06dbf2d82f049ec6b?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:3SevJWsbqUOpfPOpRZGrP9'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'single',
#                                 'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KPdmtIl0LA5mRFSqseWhI'},
#                                              'href': 'https://api.spotify.com/v1/artists/6KPdmtIl0LA5mRFSqseWhI',
#                                              'id': '6KPdmtIl0LA5mRFSqseWhI',
#                                              'name': 'Trophy Eyes',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:6KPdmtIl0LA5mRFSqseWhI'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6f6A2AiUD0r3HVygTAFgez'},
#                                 'href': 'https://api.spotify.com/v1/albums/6f6A2AiUD0r3HVygTAFgez',
#                                 'id': '6f6A2AiUD0r3HVygTAFgez',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27389acc2ddb1722821e70b0534',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0289acc2ddb1722821e70b0534',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485189acc2ddb1722821e70b0534',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Figure Eight',
#                                 'release_date': '2020-01-15',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6f6A2AiUD0r3HVygTAFgez'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KPdmtIl0LA5mRFSqseWhI'},
#                                    'href': 'https://api.spotify.com/v1/artists/6KPdmtIl0LA5mRFSqseWhI',
#                                    'id': '6KPdmtIl0LA5mRFSqseWhI',
#                                    'name': 'Trophy Eyes',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:6KPdmtIl0LA5mRFSqseWhI'}],
#                       'disc_number': 1,
#                       'duration_ms': 201556,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USHR22085001'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/70nKt5OKAbXwlRrKsrf1oq'},
#                       'href': 'https://api.spotify.com/v1/tracks/70nKt5OKAbXwlRrKsrf1oq',
#                       'id': '70nKt5OKAbXwlRrKsrf1oq',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Figure Eight',
#                       'popularity': 53,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/b22e059b06441ab601b3ba2612cca572c283d565?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:70nKt5OKAbXwlRrKsrf1oq'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#                                              'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#                                              'id': '0KDuKk6YdEu3hR56HtXmxt',
#                                              'name': 'Story Of The Year',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4juejyEeCKFskkDA6zhIBW'},
#                                 'href': 'https://api.spotify.com/v1/albums/4juejyEeCKFskkDA6zhIBW',
#                                 'id': '4juejyEeCKFskkDA6zhIBW',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734b63a12a9a503c41c4a60836',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024b63a12a9a503c41c4a60836',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514b63a12a9a503c41c4a60836',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Page Avenue',
#                                 'release_date': '2003-09-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4juejyEeCKFskkDA6zhIBW'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#                                    'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#                                    'id': '0KDuKk6YdEu3hR56HtXmxt',
#                                    'name': 'Story Of The Year',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#                       'disc_number': 1,
#                       'duration_ms': 193106,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USMV20300128'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3WsgkhWH001sMkbZVcjreS'},
#                       'href': 'https://api.spotify.com/v1/tracks/3WsgkhWH001sMkbZVcjreS',
#                       'id': '3WsgkhWH001sMkbZVcjreS',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'And the Hero Will Drown',
#                       'popularity': 53,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/c7bed8c123a7096dea4c7f9d842af56695e48f0e?cid=5371b8103cb54299a23c72d8cafa00eb',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:3WsgkhWH001sMkbZVcjreS'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-03-07T16:54:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_group': 'album',
#                                 'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7If8DXZN7mlGdQkLE2FaMo'},
#                                              'href': 'https://api.spotify.com/v1/artists/7If8DXZN7mlGdQkLE2FaMo',
#                                              'id': '7If8DXZN7mlGdQkLE2FaMo',
#                                              'name': 'The Gaslight Anthem',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7If8DXZN7mlGdQkLE2FaMo'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1gsyJWUvwjnsNgYUxpOfLR'},
#                                 'href': 'https://api.spotify.com/v1/albums/1gsyJWUvwjnsNgYUxpOfLR',
#                                 'id': '1gsyJWUvwjnsNgYUxpOfLR',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2731170b332cf9a3e4160dd057a',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e021170b332cf9a3e4160dd057a',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048511170b332cf9a3e4160dd057a',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Handwritten',
#                                 'release_date': '2012-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1gsyJWUvwjnsNgYUxpOfLR'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7If8DXZN7mlGdQkLE2FaMo'},
#                                    'href': 'https://api.spotify.com/v1/artists/7If8DXZN7mlGdQkLE2FaMo',
#                                    'id': '7If8DXZN7mlGdQkLE2FaMo',
#                                    'name': 'The Gaslight Anthem',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7If8DXZN7mlGdQkLE2FaMo'}],
#                       'disc_number': 1,
#                       'duration_ms': 207546,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBUM71202587'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5LQN7c99Q8gvmh6xJcTZgj'},
#                       'href': 'https://api.spotify.com/v1/tracks/5LQN7c99Q8gvmh6xJcTZgj',
#                       'id': '5LQN7c99Q8gvmh6xJcTZgj',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/25Sd73fleKUVPNqITPZkn1'},
#                                       'href': 'https://api.spotify.com/v1/tracks/25Sd73fleKUVPNqITPZkn1',
#                                       'id': '25Sd73fleKUVPNqITPZkn1',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:25Sd73fleKUVPNqITPZkn1'},
#                       'name': '"45"',
#                       'popularity': 54,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:5LQN7c99Q8gvmh6xJcTZgj'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 60}

# %%
# Checking the total number of songs
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is less than 100 tracks
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  60
# 60

# %%
# Defining a function that extracts the Id of the songs embebed in a playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks('spotify','37i9dQZF1DWXx3Txis2L4x')
tracks # getting a list with the info of the tracks
# Out:
# [{'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#       'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#       'id': '2qk9voo8llSGYcZ6xrBzKx',
#       'name': 'Kings of Leon',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#     'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#     'id': '5CZR6ljD0x9fTiS4mh9wMp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Only By The Night',
#     'release_date': '2008-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#      'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#      'id': '2qk9voo8llSGYcZ6xrBzKx',
#      'name': 'Kings of Leon',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#    'disc_number': 1,
#    'duration_ms': 203346,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10800300'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5A1FmxbYVRZKy4nc16MAue'},
#    'href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#    'id': '5A1FmxbYVRZKy4nc16MAue',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#     'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#     'id': '0ntQJM78wzOLVeCUAW7Y45',
#     'type': 'track',
#     'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45'},
#    'name': 'Sex on Fire',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#c97251',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#       'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#       'id': '3Ayl7mCk0nScecqOzvNp6s',
#       'name': 'Jimmy Eat World',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0UJhhj5bn5AGAjryFnhueP'},
#     'href': 'https://api.spotify.com/v1/albums/0UJhhj5bn5AGAjryFnhueP',
#     'id': '0UJhhj5bn5AGAjryFnhueP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395d1d98c5176e4f982bd73d6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295d1d98c5176e4f982bd73d6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195d1d98c5176e4f982bd73d6',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Bleed American',
#     'release_date': '2001-07-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0UJhhj5bn5AGAjryFnhueP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ayl7mCk0nScecqOzvNp6s'},
#      'href': 'https://api.spotify.com/v1/artists/3Ayl7mCk0nScecqOzvNp6s',
#      'id': '3Ayl7mCk0nScecqOzvNp6s',
#      'name': 'Jimmy Eat World',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Ayl7mCk0nScecqOzvNp6s'}],
#    'disc_number': 1,
#    'duration_ms': 165853,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USDW10110256'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GG73Jik4jUlQCkKg9JuGO'},
#    'href': 'https://api.spotify.com/v1/tracks/6GG73Jik4jUlQCkKg9JuGO',
#    'id': '6GG73Jik4jUlQCkKg9JuGO',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'The Middle',
#    'popularity': 82,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6GG73Jik4jUlQCkKg9JuGO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#       'id': '7Ln80lUS6He07XvHI8qqHH',
#       'name': 'Arctic Monkeys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#     'href': 'https://api.spotify.com/v1/albums/78bpIziExqiI9qztvNFlQu',
#     'id': '78bpIziExqiI9qztvNFlQu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ae1c4c5c45aabe565499163',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ae1c4c5c45aabe565499163',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ae1c4c5c45aabe565499163',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'AM',
#     'release_date': '2013-09-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:78bpIziExqiI9qztvNFlQu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#      'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#      'id': '7Ln80lUS6He07XvHI8qqHH',
#      'name': 'Arctic Monkeys',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#    'disc_number': 1,
#    'duration_ms': 207356,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEL1300365'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7nzsY8vlnKdvGOEE0rjAXZ'},
#    'href': 'https://api.spotify.com/v1/tracks/7nzsY8vlnKdvGOEE0rjAXZ',
#    'id': '7nzsY8vlnKdvGOEE0rjAXZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Arabella',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/974bb8b08005bbc3c38a3b1389debf8e51fa1f20?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7nzsY8vlnKdvGOEE0rjAXZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HFbH1loOUbqCyPsLuHLLh'},
#     'href': 'https://api.spotify.com/v1/albums/3HFbH1loOUbqCyPsLuHLLh',
#     'id': '3HFbH1loOUbqCyPsLuHLLh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f35726025e0f025da4c688f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f35726025e0f025da4c688f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f35726025e0f025da4c688f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Room On Fire',
#     'release_date': '2003-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3HFbH1loOUbqCyPsLuHLLh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#      'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#      'id': '0epOFNiUfyON9EYx7Tpr6V',
#      'name': 'The Strokes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#    'disc_number': 1,
#    'duration_ms': 219826,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10301519'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/57Xjny5yNzAcsxnusKmAfA'},
#    'href': 'https://api.spotify.com/v1/tracks/57Xjny5yNzAcsxnusKmAfA',
#    'id': '57Xjny5yNzAcsxnusKmAfA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Reptilia',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/35521d82091e8c9a6a1cee80fb59dc2f6b5cb776?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:57Xjny5yNzAcsxnusKmAfA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Ffb6ejR6Fe5IamqA5oRUF'},
#       'href': 'https://api.spotify.com/v1/artists/1Ffb6ejR6Fe5IamqA5oRUF',
#       'id': '1Ffb6ejR6Fe5IamqA5oRUF',
#       'name': 'Bring Me The Horizon',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7FqHuAvmREiIwVXVpZ9ooP'},
#     'href': 'https://api.spotify.com/v1/albums/7FqHuAvmREiIwVXVpZ9ooP',
#     'id': '7FqHuAvmREiIwVXVpZ9ooP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273736145b97bab8fa92cb6113f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02736145b97bab8fa92cb6113f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851736145b97bab8fa92cb6113f',
#       'width': 64}],
#     'is_playable': True,
#     'name': "That's The Spirit",
#     'release_date': '2015-09-11',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7FqHuAvmREiIwVXVpZ9ooP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Ffb6ejR6Fe5IamqA5oRUF'},
#      'href': 'https://api.spotify.com/v1/artists/1Ffb6ejR6Fe5IamqA5oRUF',
#      'id': '1Ffb6ejR6Fe5IamqA5oRUF',
#      'name': 'Bring Me The Horizon',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF'}],
#    'disc_number': 1,
#    'duration_ms': 191520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1500770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0M3adYbGtyRHACP86dey1H'},
#    'href': 'https://api.spotify.com/v1/tracks/0M3adYbGtyRHACP86dey1H',
#    'id': '0M3adYbGtyRHACP86dey1H',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Throne',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b2da695e6b81068ff4a70c1416f4bd0c45e8d894?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0M3adYbGtyRHACP86dey1H'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#e18a2e',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/24E6rDvGDuYFjlGewp4ntF'},
#     'href': 'https://api.spotify.com/v1/albums/24E6rDvGDuYFjlGewp4ntF',
#     'id': '24E6rDvGDuYFjlGewp4ntF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273053f006079bce979e5fef1e1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02053f006079bce979e5fef1e1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851053f006079bce979e5fef1e1',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Evil Empire',
#     'release_date': '1996-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:24E6rDvGDuYFjlGewp4ntF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#      'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#      'id': '2d0hyoQ5ynDBnkvAbJKORj',
#      'name': 'Rage Against The Machine',
#      'type': 'artist',
#      'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#    'disc_number': 1,
#    'duration_ms': 229466,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM19502563'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0tZ3mElWcr74OOhKEiNz1x'},
#    'href': 'https://api.spotify.com/v1/tracks/0tZ3mElWcr74OOhKEiNz1x',
#    'id': '0tZ3mElWcr74OOhKEiNz1x',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bulls On Parade',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c1626784be02379a8ec2fa5f7d7f735c1eda772b?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0tZ3mElWcr74OOhKEiNz1x'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03r4iKL2g2442PT9n2UKsx'},
#       'href': 'https://api.spotify.com/v1/artists/03r4iKL2g2442PT9n2UKsx',
#       'id': '03r4iKL2g2442PT9n2UKsx',
#       'name': 'Beastie Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:03r4iKL2g2442PT9n2UKsx'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6lfjbwFGzQ6aSNP1N3JlT8'},
#     'href': 'https://api.spotify.com/v1/albums/6lfjbwFGzQ6aSNP1N3JlT8',
#     'id': '6lfjbwFGzQ6aSNP1N3JlT8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273436a305db8bd85b820da3e5a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02436a305db8bd85b820da3e5a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851436a305db8bd85b820da3e5a',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Ill Communication',
#     'release_date': '1994-05-23',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:6lfjbwFGzQ6aSNP1N3JlT8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/03r4iKL2g2442PT9n2UKsx'},
#      'href': 'https://api.spotify.com/v1/artists/03r4iKL2g2442PT9n2UKsx',
#      'id': '03r4iKL2g2442PT9n2UKsx',
#      'name': 'Beastie Boys',
#      'type': 'artist',
#      'uri': 'spotify:artist:03r4iKL2g2442PT9n2UKsx'}],
#    'disc_number': 1,
#    'duration_ms': 178440,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USCA29400020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Puj4YlTm6xNzDDADXHMI9'},
#    'href': 'https://api.spotify.com/v1/tracks/0Puj4YlTm6xNzDDADXHMI9',
#    'id': '0Puj4YlTm6xNzDDADXHMI9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sabotage',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0Puj4YlTm6xNzDDADXHMI9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#948672',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#       'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#       'id': '7mnBLXK823vNxN3UWB7Gfz',
#       'name': 'The Black Keys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5DLhV9yOvZ7IxVmljMXtNm'},
#     'href': 'https://api.spotify.com/v1/albums/5DLhV9yOvZ7IxVmljMXtNm',
#     'id': '5DLhV9yOvZ7IxVmljMXtNm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736a21b97de47168df4f0c1993',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026a21b97de47168df4f0c1993',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516a21b97de47168df4f0c1993',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'El Camino',
#     'release_date': '2011-12-06',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5DLhV9yOvZ7IxVmljMXtNm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#      'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#      'id': '7mnBLXK823vNxN3UWB7Gfz',
#      'name': 'The Black Keys',
#      'type': 'artist',
#      'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#    'disc_number': 1,
#    'duration_ms': 193653,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USNO11100273'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5G1sTBGbZT5o4PNRc75RKI'},
#    'href': 'https://api.spotify.com/v1/tracks/5G1sTBGbZT5o4PNRc75RKI',
#    'id': '5G1sTBGbZT5o4PNRc75RKI',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Lonely Boy',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cb384c17027f77dd419356db04186415edea2b90?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5G1sTBGbZT5o4PNRc75RKI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#       'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#       'id': '7jy3rLJdDQY21OgRLCZ9sD',
#       'name': 'Foo Fighters',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1zQ6F8gMagKcPL4SoA80cx'},
#     'href': 'https://api.spotify.com/v1/albums/1zQ6F8gMagKcPL4SoA80cx',
#     'id': '1zQ6F8gMagKcPL4SoA80cx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b00ee453b3496535eaa6e4b3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b00ee453b3496535eaa6e4b3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b00ee453b3496535eaa6e4b3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'One By One (Expanded Edition)',
#     'release_date': '2002-10-22',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:1zQ6F8gMagKcPL4SoA80cx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#      'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#      'id': '7jy3rLJdDQY21OgRLCZ9sD',
#      'name': 'Foo Fighters',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#    'disc_number': 1,
#    'duration_ms': 263440,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRW30200001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6tsojOQ5wHaIjKqIryLZK6'},
#    'href': 'https://api.spotify.com/v1/tracks/6tsojOQ5wHaIjKqIryLZK6',
#    'id': '6tsojOQ5wHaIjKqIryLZK6',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'All My Life',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f3cf56a45924d4cecd7ed50becfa51ec84a41e3c?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6tsojOQ5wHaIjKqIryLZK6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YcBF2ttyueytpXtEzn1Za'},
#       'href': 'https://api.spotify.com/v1/artists/3YcBF2ttyueytpXtEzn1Za',
#       'id': '3YcBF2ttyueytpXtEzn1Za',
#       'name': 'Incubus',
#       'type': 'artist',
#       'uri': 'spotify:artist:3YcBF2ttyueytpXtEzn1Za'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1rQZbncicoXyB64DqoH7OY'},
#     'href': 'https://api.spotify.com/v1/albums/1rQZbncicoXyB64DqoH7OY',
#     'id': '1rQZbncicoXyB64DqoH7OY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273289320ef78f164a472698926',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02289320ef78f164a472698926',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851289320ef78f164a472698926',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Morning View',
#     'release_date': '2001-10-23',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1rQZbncicoXyB64DqoH7OY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YcBF2ttyueytpXtEzn1Za'},
#      'href': 'https://api.spotify.com/v1/artists/3YcBF2ttyueytpXtEzn1Za',
#      'id': '3YcBF2ttyueytpXtEzn1Za',
#      'name': 'Incubus',
#      'type': 'artist',
#      'uri': 'spotify:artist:3YcBF2ttyueytpXtEzn1Za'}],
#    'disc_number': 1,
#    'duration_ms': 212733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10107084'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6KtLECDztnah63TNmV4Plw'},
#    'href': 'https://api.spotify.com/v1/tracks/6KtLECDztnah63TNmV4Plw',
#    'id': '6KtLECDztnah63TNmV4Plw',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Wish You Were Here',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3c423190127a2748aad13610df1d44a36f45c956?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6KtLECDztnah63TNmV4Plw'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#     'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#     'id': '37Q22g0n9PzBLX6lNddrIa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Kiss Me, Kiss Me, Kiss Me',
#     'release_date': '1987-05-25',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'disc_number': 1,
#    'duration_ms': 212013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBALB8700003'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4NnWuGQujzWUEg0uZokO5M'},
#    'href': 'https://api.spotify.com/v1/tracks/4NnWuGQujzWUEg0uZokO5M',
#    'id': '4NnWuGQujzWUEg0uZokO5M',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#     'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#     'id': '76GlO5H5RT6g7y0gev86Nk',
#     'type': 'track',
#     'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#    'name': 'Just Like Heaven',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4NnWuGQujzWUEg0uZokO5M'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#729c84',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#       'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#       'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#       'name': 'My Chemical Romance',
#       'type': 'artist',
#       'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2wPnKggTK3QhYAKL7Q0vvr'},
#     'href': 'https://api.spotify.com/v1/albums/2wPnKggTK3QhYAKL7Q0vvr',
#     'id': '2wPnKggTK3QhYAKL7Q0vvr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736fbf4bb780a9cbc34b3f35da',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026fbf4bb780a9cbc34b3f35da',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516fbf4bb780a9cbc34b3f35da',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Danger Days: The True Lives of the Fabulous Killjoys',
#     'release_date': '2010-11-05',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2wPnKggTK3QhYAKL7Q0vvr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FBcuc1gsnv6Y1nwFtNRCb'},
#      'href': 'https://api.spotify.com/v1/artists/7FBcuc1gsnv6Y1nwFtNRCb',
#      'id': '7FBcuc1gsnv6Y1nwFtNRCb',
#      'name': 'My Chemical Romance',
#      'type': 'artist',
#      'uri': 'spotify:artist:7FBcuc1gsnv6Y1nwFtNRCb'}],
#    'disc_number': 1,
#    'duration_ms': 205960,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USRE11000909'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5BB0Jzw60KyfSTyjJqtely'},
#    'href': 'https://api.spotify.com/v1/tracks/5BB0Jzw60KyfSTyjJqtely',
#    'id': '5BB0Jzw60KyfSTyjJqtely',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Na Na Na (Na Na Na Na Na Na Na Na Na)',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7aaaf546b7735a3277022ef9dc8568e29fdf78a0?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5BB0Jzw60KyfSTyjJqtely'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#       'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#       'id': '6XyY86QOPPrYVGvF9ch6wz',
#       'name': 'Linkin Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'},
#     'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3',
#     'id': '4Gfnly5CzMJQqkUFfoHaP3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b4ad7ebaf4575f120eb3f193',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b4ad7ebaf4575f120eb3f193',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b4ad7ebaf4575f120eb3f193',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Meteora',
#     'release_date': '2003-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4Gfnly5CzMJQqkUFfoHaP3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#      'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#      'id': '6XyY86QOPPrYVGvF9ch6wz',
#      'name': 'Linkin Park',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#    'disc_number': 1,
#    'duration_ms': 213933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB10300376'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3agtg0x11wPvLIWkYR39nZ'},
#    'href': 'https://api.spotify.com/v1/tracks/3agtg0x11wPvLIWkYR39nZ',
#    'id': '3agtg0x11wPvLIWkYR39nZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Somewhere I Belong',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d31420e7f4ad2284dd8b7e001d005c727dc14b16?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3agtg0x11wPvLIWkYR39nZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#       'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#       'id': '3jOstUTkEu2JkjvRdBA5Gu',
#       'name': 'Weezer',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2OBSz5Nlto0Q5CtYPzPY7c'},
#     'href': 'https://api.spotify.com/v1/albums/2OBSz5Nlto0Q5CtYPzPY7c',
#     'id': '2OBSz5Nlto0Q5CtYPzPY7c',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731e0dc5baaabda304b0ad1815',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021e0dc5baaabda304b0ad1815',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511e0dc5baaabda304b0ad1815',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Weezer',
#     'release_date': '2001-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2OBSz5Nlto0Q5CtYPzPY7c'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#      'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#      'id': '3jOstUTkEu2JkjvRdBA5Gu',
#      'name': 'Weezer',
#      'type': 'artist',
#      'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#    'disc_number': 1,
#    'duration_ms': 185960,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10110319'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3GcVQCRSaPNupmf65YKyQI'},
#    'href': 'https://api.spotify.com/v1/tracks/3GcVQCRSaPNupmf65YKyQI',
#    'id': '3GcVQCRSaPNupmf65YKyQI',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2mPMFJvQ0v27gVqe5b6nDn'},
#     'href': 'https://api.spotify.com/v1/tracks/2mPMFJvQ0v27gVqe5b6nDn',
#     'id': '2mPMFJvQ0v27gVqe5b6nDn',
#     'type': 'track',
#     'uri': 'spotify:track:2mPMFJvQ0v27gVqe5b6nDn'},
#    'name': 'Hash Pipe',
#    'popularity': 52,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3GcVQCRSaPNupmf65YKyQI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2eia0myWFgoHuttJytCxgX'},
#     'href': 'https://api.spotify.com/v1/albums/2eia0myWFgoHuttJytCxgX',
#     'id': '2eia0myWFgoHuttJytCxgX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733c2579a4f8cacd5b95b8fa68',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023c2579a4f8cacd5b95b8fa68',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513c2579a4f8cacd5b95b8fa68',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'The Battle Of Los Angeles',
#     'release_date': '1999-11-02',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2eia0myWFgoHuttJytCxgX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#      'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#      'id': '2d0hyoQ5ynDBnkvAbJKORj',
#      'name': 'Rage Against The Machine',
#      'type': 'artist',
#      'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#    'disc_number': 1,
#    'duration_ms': 205600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19920168'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1MQTmpYOZ6fcMQc56Hdo7T'},
#    'href': 'https://api.spotify.com/v1/tracks/1MQTmpYOZ6fcMQc56Hdo7T',
#    'id': '1MQTmpYOZ6fcMQc56Hdo7T',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sleep Now In the Fire',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d01a72ff6f8a80a2af4e429c7772853aab6807f7?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1MQTmpYOZ6fcMQc56Hdo7T'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T11:30:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08yf5A2nS4XEeNvabDXqyg'},
#       'href': 'https://api.spotify.com/v1/artists/08yf5A2nS4XEeNvabDXqyg',
#       'id': '08yf5A2nS4XEeNvabDXqyg',
#       'name': 'Billy Talent',
#       'type': 'artist',
#       'uri': 'spotify:artist:08yf5A2nS4XEeNvabDXqyg'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0cTOvcvrbNiaiv4WXEUHzT'},
#     'href': 'https://api.spotify.com/v1/albums/0cTOvcvrbNiaiv4WXEUHzT',
#     'id': '0cTOvcvrbNiaiv4WXEUHzT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27351ad1636a7d0456ad972a71c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0251ad1636a7d0456ad972a71c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485151ad1636a7d0456ad972a71c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Billy Talent II',
#     'release_date': '2006-06-23',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0cTOvcvrbNiaiv4WXEUHzT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08yf5A2nS4XEeNvabDXqyg'},
#      'href': 'https://api.spotify.com/v1/artists/08yf5A2nS4XEeNvabDXqyg',
#      'id': '08yf5A2nS4XEeNvabDXqyg',
#      'name': 'Billy Talent',
#      'type': 'artist',
#      'uri': 'spotify:artist:08yf5A2nS4XEeNvabDXqyg'}],
#    'disc_number': 1,
#    'duration_ms': 196840,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT20612281'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0cJFobGkaiupCsOfE2eBZ1'},
#    'href': 'https://api.spotify.com/v1/tracks/0cJFobGkaiupCsOfE2eBZ1',
#    'id': '0cJFobGkaiupCsOfE2eBZ1',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2RZWdE8kYPlCAcRUYDeuLC'},
#     'href': 'https://api.spotify.com/v1/tracks/2RZWdE8kYPlCAcRUYDeuLC',
#     'id': '2RZWdE8kYPlCAcRUYDeuLC',
#     'type': 'track',
#     'uri': 'spotify:track:2RZWdE8kYPlCAcRUYDeuLC'},
#    'name': 'Red Flag',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2a0ce6e4c91d76215e8b68b3e17df5db804e7e93?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0cJFobGkaiupCsOfE2eBZ1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#9ec9e3',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NiJW4q9ichVqL1aUsgGAN'},
#       'href': 'https://api.spotify.com/v1/artists/4NiJW4q9ichVqL1aUsgGAN',
#       'id': '4NiJW4q9ichVqL1aUsgGAN',
#       'name': 'A Day To Remember',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NiJW4q9ichVqL1aUsgGAN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6I2SUr0MolRUiDEcZAbSWm'},
#     'href': 'https://api.spotify.com/v1/albums/6I2SUr0MolRUiDEcZAbSWm',
#     'id': '6I2SUr0MolRUiDEcZAbSWm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739233270031da763169e5f96c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029233270031da763169e5f96c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519233270031da763169e5f96c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'What Separates Me From You',
#     'release_date': '2010-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6I2SUr0MolRUiDEcZAbSWm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NiJW4q9ichVqL1aUsgGAN'},
#      'href': 'https://api.spotify.com/v1/artists/4NiJW4q9ichVqL1aUsgGAN',
#      'id': '4NiJW4q9ichVqL1aUsgGAN',
#      'name': 'A Day To Remember',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NiJW4q9ichVqL1aUsgGAN'}],
#    'disc_number': 1,
#    'duration_ms': 202640,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVIC1060302'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4JsDHMv5PVO8N07DbDq33r'},
#    'href': 'https://api.spotify.com/v1/tracks/4JsDHMv5PVO8N07DbDq33r',
#    'id': '4JsDHMv5PVO8N07DbDq33r',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'All I Want',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4JsDHMv5PVO8N07DbDq33r'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#       'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#       'id': '4F84IBURUo98rz4r61KF70',
#       'name': 'The White Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3rHeq4F5wnaLBjNtuz7Yvh'},
#     'href': 'https://api.spotify.com/v1/albums/3rHeq4F5wnaLBjNtuz7Yvh',
#     'id': '3rHeq4F5wnaLBjNtuz7Yvh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e8a1ae591befe4bb0a9261ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e8a1ae591befe4bb0a9261ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e8a1ae591befe4bb0a9261ab',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Get Behind Me Satan',
#     'release_date': '2005-06-07',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:3rHeq4F5wnaLBjNtuz7Yvh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#      'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#      'id': '4F84IBURUo98rz4r61KF70',
#      'name': 'The White Stripes',
#      'type': 'artist',
#      'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#    'disc_number': 1,
#    'duration_ms': 157560,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVT10500076'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4jU7NPkz4HVnM4hweqNhI1'},
#    'href': 'https://api.spotify.com/v1/tracks/4jU7NPkz4HVnM4hweqNhI1',
#    'id': '4jU7NPkz4HVnM4hweqNhI1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Blue Orchid',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2e9b9fa30244c8672653449fab018930b31250c7?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4jU7NPkz4HVnM4hweqNhI1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yEnArbNHyTCwMRvD9SBy4'},
#       'href': 'https://api.spotify.com/v1/artists/3yEnArbNHyTCwMRvD9SBy4',
#       'id': '3yEnArbNHyTCwMRvD9SBy4',
#       'name': 'Wolfmother',
#       'type': 'artist',
#       'uri': 'spotify:artist:3yEnArbNHyTCwMRvD9SBy4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ywynDHLHT3l8QSu41TcmC'},
#     'href': 'https://api.spotify.com/v1/albums/5ywynDHLHT3l8QSu41TcmC',
#     'id': '5ywynDHLHT3l8QSu41TcmC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27304422c5d997bfa6c750a12f1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0204422c5d997bfa6c750a12f1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485104422c5d997bfa6c750a12f1',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Wolfmother',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5ywynDHLHT3l8QSu41TcmC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yEnArbNHyTCwMRvD9SBy4'},
#      'href': 'https://api.spotify.com/v1/artists/3yEnArbNHyTCwMRvD9SBy4',
#      'id': '3yEnArbNHyTCwMRvD9SBy4',
#      'name': 'Wolfmother',
#      'type': 'artist',
#      'uri': 'spotify:artist:3yEnArbNHyTCwMRvD9SBy4'}],
#    'disc_number': 1,
#    'duration_ms': 280466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUUM70500115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7ISL3LO8AWP3fKIXunvqTa'},
#    'href': 'https://api.spotify.com/v1/tracks/7ISL3LO8AWP3fKIXunvqTa',
#    'id': '7ISL3LO8AWP3fKIXunvqTa',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Joker And The Thief',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
# ...
#    'href': 'https://api.spotify.com/v1/tracks/0KEhlgtlk0HuqBIqfGCGdF',
#    'id': '0KEhlgtlk0HuqBIqfGCGdF',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'State of Love and Trust',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b47bb4bc677298d1b062c1d84b0825b86118a7d5?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0KEhlgtlk0HuqBIqfGCGdF'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#999999',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2S5hlvw4CMtMGswFtfdK15'},
#       'href': 'https://api.spotify.com/v1/artists/2S5hlvw4CMtMGswFtfdK15',
#       'id': '2S5hlvw4CMtMGswFtfdK15',
#       'name': 'Royal Blood',
#       'type': 'artist',
#       'uri': 'spotify:artist:2S5hlvw4CMtMGswFtfdK15'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7DJijwZ2wqJrgLpcRMxs3G'},
#     'href': 'https://api.spotify.com/v1/albums/7DJijwZ2wqJrgLpcRMxs3G',
#     'id': '7DJijwZ2wqJrgLpcRMxs3G',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735009d126076953c572800954',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025009d126076953c572800954',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515009d126076953c572800954',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Royal Blood',
#     'release_date': '2014-08-25',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7DJijwZ2wqJrgLpcRMxs3G'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2S5hlvw4CMtMGswFtfdK15'},
#      'href': 'https://api.spotify.com/v1/artists/2S5hlvw4CMtMGswFtfdK15',
#      'id': '2S5hlvw4CMtMGswFtfdK15',
#      'name': 'Royal Blood',
#      'type': 'artist',
#      'uri': 'spotify:artist:2S5hlvw4CMtMGswFtfdK15'}],
#    'disc_number': 1,
#    'duration_ms': 240572,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAHT1400097'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1INksmStBpxdNlBzwGUvsg'},
#    'href': 'https://api.spotify.com/v1/tracks/1INksmStBpxdNlBzwGUvsg',
#    'id': '1INksmStBpxdNlBzwGUvsg',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2nIulsLMiP2SMTDrtxfQXX'},
#     'href': 'https://api.spotify.com/v1/tracks/2nIulsLMiP2SMTDrtxfQXX',
#     'id': '2nIulsLMiP2SMTDrtxfQXX',
#     'type': 'track',
#     'uri': 'spotify:track:2nIulsLMiP2SMTDrtxfQXX'},
#    'name': 'Out of the Black',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/284191332fe4ecb0f3dbb06598356a595aaf8b57?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1INksmStBpxdNlBzwGUvsg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55VydwMyCuGcavwPuhutPL'},
#       'href': 'https://api.spotify.com/v1/artists/55VydwMyCuGcavwPuhutPL',
#       'id': '55VydwMyCuGcavwPuhutPL',
#       'name': 'The Used',
#       'type': 'artist',
#       'uri': 'spotify:artist:55VydwMyCuGcavwPuhutPL'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2UMvo9uU74jGUArNX7C7qT'},
#     'href': 'https://api.spotify.com/v1/albums/2UMvo9uU74jGUArNX7C7qT',
#     'id': '2UMvo9uU74jGUArNX7C7qT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731b85ebc510845f8c994a8f56',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021b85ebc510845f8c994a8f56',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511b85ebc510845f8c994a8f56',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Imaginary Enemy',
#     'release_date': '2014-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2UMvo9uU74jGUArNX7C7qT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55VydwMyCuGcavwPuhutPL'},
#      'href': 'https://api.spotify.com/v1/artists/55VydwMyCuGcavwPuhutPL',
#      'id': '55VydwMyCuGcavwPuhutPL',
#      'name': 'The Used',
#      'type': 'artist',
#      'uri': 'spotify:artist:55VydwMyCuGcavwPuhutPL'}],
#    'disc_number': 1,
#    'duration_ms': 210133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHR21473003'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7jKziCSFvitg68mOsTd7RL'},
#    'href': 'https://api.spotify.com/v1/tracks/7jKziCSFvitg68mOsTd7RL',
#    'id': '7jKziCSFvitg68mOsTd7RL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cry',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/34e5c38539a9a9daa2276979ae5d56240f18de9c?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7jKziCSFvitg68mOsTd7RL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': '#ece136',
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kNQXvepPjaPgUfeDAF2h6'},
#       'href': 'https://api.spotify.com/v1/artists/1kNQXvepPjaPgUfeDAF2h6',
#       'id': '1kNQXvepPjaPgUfeDAF2h6',
#       'name': 'You Me At Six',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kNQXvepPjaPgUfeDAF2h6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0S9IWlmYkM6ULSB1BExd5t'},
#     'href': 'https://api.spotify.com/v1/albums/0S9IWlmYkM6ULSB1BExd5t',
#     'id': '0S9IWlmYkM6ULSB1BExd5t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273832f747b8b2d5c9a71f4a97f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02832f747b8b2d5c9a71f4a97f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851832f747b8b2d5c9a71f4a97f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'SUCKAPUNCH',
#     'release_date': '2021-01-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0S9IWlmYkM6ULSB1BExd5t'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kNQXvepPjaPgUfeDAF2h6'},
#      'href': 'https://api.spotify.com/v1/artists/1kNQXvepPjaPgUfeDAF2h6',
#      'id': '1kNQXvepPjaPgUfeDAF2h6',
#      'name': 'You Me At Six',
#      'type': 'artist',
#      'uri': 'spotify:artist:1kNQXvepPjaPgUfeDAF2h6'}],
#    'disc_number': 1,
#    'duration_ms': 225786,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBKPL2018245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3SevJWsbqUOpfPOpRZGrP9'},
#    'href': 'https://api.spotify.com/v1/tracks/3SevJWsbqUOpfPOpRZGrP9',
#    'id': '3SevJWsbqUOpfPOpRZGrP9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Beautiful Way',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a8e571d6fd57acd96b16bea06dbf2d82f049ec6b?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3SevJWsbqUOpfPOpRZGrP9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KPdmtIl0LA5mRFSqseWhI'},
#       'href': 'https://api.spotify.com/v1/artists/6KPdmtIl0LA5mRFSqseWhI',
#       'id': '6KPdmtIl0LA5mRFSqseWhI',
#       'name': 'Trophy Eyes',
#       'type': 'artist',
#       'uri': 'spotify:artist:6KPdmtIl0LA5mRFSqseWhI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6f6A2AiUD0r3HVygTAFgez'},
#     'href': 'https://api.spotify.com/v1/albums/6f6A2AiUD0r3HVygTAFgez',
#     'id': '6f6A2AiUD0r3HVygTAFgez',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27389acc2ddb1722821e70b0534',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0289acc2ddb1722821e70b0534',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485189acc2ddb1722821e70b0534',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Figure Eight',
#     'release_date': '2020-01-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6f6A2AiUD0r3HVygTAFgez'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KPdmtIl0LA5mRFSqseWhI'},
#      'href': 'https://api.spotify.com/v1/artists/6KPdmtIl0LA5mRFSqseWhI',
#      'id': '6KPdmtIl0LA5mRFSqseWhI',
#      'name': 'Trophy Eyes',
#      'type': 'artist',
#      'uri': 'spotify:artist:6KPdmtIl0LA5mRFSqseWhI'}],
#    'disc_number': 1,
#    'duration_ms': 201556,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHR22085001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/70nKt5OKAbXwlRrKsrf1oq'},
#    'href': 'https://api.spotify.com/v1/tracks/70nKt5OKAbXwlRrKsrf1oq',
#    'id': '70nKt5OKAbXwlRrKsrf1oq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Figure Eight',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b22e059b06441ab601b3ba2612cca572c283d565?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:70nKt5OKAbXwlRrKsrf1oq'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#       'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#       'id': '0KDuKk6YdEu3hR56HtXmxt',
#       'name': 'Story Of The Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4juejyEeCKFskkDA6zhIBW'},
#     'href': 'https://api.spotify.com/v1/albums/4juejyEeCKFskkDA6zhIBW',
#     'id': '4juejyEeCKFskkDA6zhIBW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734b63a12a9a503c41c4a60836',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024b63a12a9a503c41c4a60836',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514b63a12a9a503c41c4a60836',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Page Avenue',
#     'release_date': '2003-09-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4juejyEeCKFskkDA6zhIBW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#      'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#      'id': '0KDuKk6YdEu3hR56HtXmxt',
#      'name': 'Story Of The Year',
#      'type': 'artist',
#      'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#    'disc_number': 1,
#    'duration_ms': 193106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMV20300128'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3WsgkhWH001sMkbZVcjreS'},
#    'href': 'https://api.spotify.com/v1/tracks/3WsgkhWH001sMkbZVcjreS',
#    'id': '3WsgkhWH001sMkbZVcjreS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'And the Hero Will Drown',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c7bed8c123a7096dea4c7f9d842af56695e48f0e?cid=5371b8103cb54299a23c72d8cafa00eb',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3WsgkhWH001sMkbZVcjreS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-03-07T16:54:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7If8DXZN7mlGdQkLE2FaMo'},
#       'href': 'https://api.spotify.com/v1/artists/7If8DXZN7mlGdQkLE2FaMo',
#       'id': '7If8DXZN7mlGdQkLE2FaMo',
#       'name': 'The Gaslight Anthem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7If8DXZN7mlGdQkLE2FaMo'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1gsyJWUvwjnsNgYUxpOfLR'},
#     'href': 'https://api.spotify.com/v1/albums/1gsyJWUvwjnsNgYUxpOfLR',
#     'id': '1gsyJWUvwjnsNgYUxpOfLR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731170b332cf9a3e4160dd057a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021170b332cf9a3e4160dd057a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511170b332cf9a3e4160dd057a',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Handwritten',
#     'release_date': '2012-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1gsyJWUvwjnsNgYUxpOfLR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7If8DXZN7mlGdQkLE2FaMo'},
#      'href': 'https://api.spotify.com/v1/artists/7If8DXZN7mlGdQkLE2FaMo',
#      'id': '7If8DXZN7mlGdQkLE2FaMo',
#      'name': 'The Gaslight Anthem',
#      'type': 'artist',
#      'uri': 'spotify:artist:7If8DXZN7mlGdQkLE2FaMo'}],
#    'disc_number': 1,
#    'duration_ms': 207546,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71202587'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5LQN7c99Q8gvmh6xJcTZgj'},
#    'href': 'https://api.spotify.com/v1/tracks/5LQN7c99Q8gvmh6xJcTZgj',
#    'id': '5LQN7c99Q8gvmh6xJcTZgj',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/25Sd73fleKUVPNqITPZkn1'},
#     'href': 'https://api.spotify.com/v1/tracks/25Sd73fleKUVPNqITPZkn1',
#     'id': '25Sd73fleKUVPNqITPZkn1',
#     'type': 'track',
#     'uri': 'spotify:track:25Sd73fleKUVPNqITPZkn1'},
#    'name': '"45"',
#    'popularity': 54,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5LQN7c99Q8gvmh6xJcTZgj'},
#   'video_thumbnail': {'url': None}}]

# %% [markdown]
# extracting the songs ids from playlist

# %%
# Extracting the audio_features of a track
sp.audio_features(tracks[0]["track"]["id"])
# Out:
# [{'danceability': 0.542,
#   'energy': 0.905,
#   'key': 9,
#   'loudness': -5.653,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.0104,
#   'liveness': 0.136,
#   'valence': 0.374,
#   'tempo': 153.398,
#   'type': 'audio_features',
#   'id': '5A1FmxbYVRZKy4nc16MAue',
#   'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue',
#   'track_href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5A1FmxbYVRZKy4nc16MAue',
#   'duration_ms': 203347,
#   'time_signature': 4}]

# %%
tracks[0]
# Out:
# {'added_at': '2023-03-07T16:54:09Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#      'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#      'id': '2qk9voo8llSGYcZ6xrBzKx',
#      'name': 'Kings of Leon',
#      'type': 'artist',
#      'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5CZR6ljD0x9fTiS4mh9wMp'},
#    'href': 'https://api.spotify.com/v1/albums/5CZR6ljD0x9fTiS4mh9wMp',
#    'id': '5CZR6ljD0x9fTiS4mh9wMp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732519d01c0cca06f134eeadd8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022519d01c0cca06f134eeadd8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512519d01c0cca06f134eeadd8',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Only By The Night',
#    'release_date': '2008-09-23',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:5CZR6ljD0x9fTiS4mh9wMp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#     'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#     'id': '2qk9voo8llSGYcZ6xrBzKx',
#     'name': 'Kings of Leon',
#     'type': 'artist',
#     'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#   'disc_number': 1,
#   'duration_ms': 203346,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USRC10800300'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5A1FmxbYVRZKy4nc16MAue'},
#   'href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#   'id': '5A1FmxbYVRZKy4nc16MAue',
#   'is_local': False,
#   'is_playable': True,
#   'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45'},
#    'href': 'https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45',
#    'id': '0ntQJM78wzOLVeCUAW7Y45',
#    'type': 'track',
#    'uri': 'spotify:track:0ntQJM78wzOLVeCUAW7Y45'},
#   'name': 'Sex on Fire',
#   'popularity': 71,
#   'preview_url': 'https://p.scdn.co/mp3-preview/6806855988e246016413cc8a34a2afe862f3988d?cid=5371b8103cb54299a23c72d8cafa00eb',
#   'track': True,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue'},
#  'video_thumbnail': {'url': None}}

# %%
# Creating a list of features with the features of all tracks in the playlist
list_of_audio_features = []
for item in range(0,60):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.542,
#   'energy': 0.905,
#   'key': 9,
#   'loudness': -5.653,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.0104,
#   'liveness': 0.136,
#   'valence': 0.374,
#   'tempo': 153.398,
#   'type': 'audio_features',
#   'id': '5A1FmxbYVRZKy4nc16MAue',
#   'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue',
#   'track_href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5A1FmxbYVRZKy4nc16MAue',
#   'duration_ms': 203347,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.849,
#   'key': 2,
#   'loudness': -5.428,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.0371,
#   'instrumentalness': 0,
#   'liveness': 0.058,
#   'valence': 0.903,
#   'tempo': 162.152,
#   'type': 'audio_features',
#   'id': '6GG73Jik4jUlQCkKg9JuGO',
#   'uri': 'spotify:track:6GG73Jik4jUlQCkKg9JuGO',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GG73Jik4jUlQCkKg9JuGO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GG73Jik4jUlQCkKg9JuGO',
#   'duration_ms': 165853,
#   'time_signature': 4},
#  {'danceability': 0.579,
#   'energy': 0.558,
#   'key': 2,
#   'loudness': -6.986,
#   'mode': 1,
#   'speechiness': 0.0895,
#   'acousticness': 0.0202,
#   'instrumentalness': 1.26e-06,
#   'liveness': 0.212,
#   'valence': 0.506,
#   'tempo': 179.949,
#   'type': 'audio_features',
#   'id': '7nzsY8vlnKdvGOEE0rjAXZ',
#   'uri': 'spotify:track:7nzsY8vlnKdvGOEE0rjAXZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nzsY8vlnKdvGOEE0rjAXZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nzsY8vlnKdvGOEE0rjAXZ',
#   'duration_ms': 207357,
#   'time_signature': 4},
#  {'danceability': 0.489,
#   'energy': 0.649,
#   'key': 9,
#   'loudness': -5.11,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.000603,
#   'instrumentalness': 0.713,
#   'liveness': 0.101,
#   'valence': 0.77,
#   'tempo': 158.009,
#   'type': 'audio_features',
#   'id': '57Xjny5yNzAcsxnusKmAfA',
#   'uri': 'spotify:track:57Xjny5yNzAcsxnusKmAfA',
#   'track_href': 'https://api.spotify.com/v1/tracks/57Xjny5yNzAcsxnusKmAfA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57Xjny5yNzAcsxnusKmAfA',
#   'duration_ms': 219827,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.888,
#   'key': 0,
#   'loudness': -3.72,
#   'mode': 0,
#   'speechiness': 0.0987,
#   'acousticness': 0.000455,
#   'instrumentalness': 0,
#   'liveness': 0.306,
#   'valence': 0.387,
#   'tempo': 144.111,
#   'type': 'audio_features',
#   'id': '0M3adYbGtyRHACP86dey1H',
#   'uri': 'spotify:track:0M3adYbGtyRHACP86dey1H',
#   'track_href': 'https://api.spotify.com/v1/tracks/0M3adYbGtyRHACP86dey1H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0M3adYbGtyRHACP86dey1H',
#   'duration_ms': 191520,
#   'time_signature': 4},
#  {'danceability': 0.412,
#   'energy': 0.919,
#   'key': 5,
#   'loudness': -7.291,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.0124,
#   'instrumentalness': 0.0601,
#   'liveness': 0.424,
#   'valence': 0.572,
#   'tempo': 166.367,
#   'type': 'audio_features',
#   'id': '0tZ3mElWcr74OOhKEiNz1x',
#   'uri': 'spotify:track:0tZ3mElWcr74OOhKEiNz1x',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tZ3mElWcr74OOhKEiNz1x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tZ3mElWcr74OOhKEiNz1x',
#   'duration_ms': 229467,
#   'time_signature': 4},
#  {'danceability': 0.324,
#   'energy': 0.938,
#   'key': 6,
#   'loudness': -7.332,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.032,
#   'instrumentalness': 0.0321,
#   'liveness': 0.0961,
#   'valence': 0.543,
#   'tempo': 168.131,
#   'type': 'audio_features',
#   'id': '0Puj4YlTm6xNzDDADXHMI9',
#   'uri': 'spotify:track:0Puj4YlTm6xNzDDADXHMI9',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Puj4YlTm6xNzDDADXHMI9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Puj4YlTm6xNzDDADXHMI9',
#   'duration_ms': 178440,
#   'time_signature': 4},
#  {'danceability': 0.356,
#   'energy': 0.872,
#   'key': 2,
#   'loudness': -7.837,
#   'mode': 1,
#   'speechiness': 0.068,
#   'acousticness': 0.00417,
#   'instrumentalness': 0.00975,
#   'liveness': 0.0997,
#   'valence': 0.607,
#   'tempo': 166.3,
#   'type': 'audio_features',
#   'id': '5G1sTBGbZT5o4PNRc75RKI',
#   'uri': 'spotify:track:5G1sTBGbZT5o4PNRc75RKI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5G1sTBGbZT5o4PNRc75RKI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5G1sTBGbZT5o4PNRc75RKI',
#   'duration_ms': 193653,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.604,
#   'key': 5,
#   'loudness': -5.703,
#   'mode': 1,
#   'speechiness': 0.0495,
#   'acousticness': 0.000218,
#   'instrumentalness': 0.000579,
#   'liveness': 0.477,
#   'valence': 0.637,
#   'tempo': 167.719,
#   'type': 'audio_features',
#   'id': '6tsojOQ5wHaIjKqIryLZK6',
#   'uri': 'spotify:track:6tsojOQ5wHaIjKqIryLZK6',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tsojOQ5wHaIjKqIryLZK6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tsojOQ5wHaIjKqIryLZK6',
#   'duration_ms': 263440,
#   'time_signature': 4},
#  {'danceability': 0.246,
#   'energy': 0.768,
#   'key': 9,
#   'loudness': -7.48,
#   'mode': 1,
#   'speechiness': 0.0387,
#   'acousticness': 0.000631,
#   'instrumentalness': 0.301,
#   'liveness': 0.102,
#   'valence': 0.35,
#   'tempo': 169.873,
#   'type': 'audio_features',
#   'id': '6KtLECDztnah63TNmV4Plw',
#   'uri': 'spotify:track:6KtLECDztnah63TNmV4Plw',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KtLECDztnah63TNmV4Plw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KtLECDztnah63TNmV4Plw',
#   'duration_ms': 212733,
#   'time_signature': 4},
#  {'danceability': 0.437,
#   'energy': 0.94,
#   'key': 9,
#   'loudness': -6.946,
#   'mode': 1,
#   'speechiness': 0.0426,
#   'acousticness': 0.0524,
#   'instrumentalness': 0.000573,
#   'liveness': 0.222,
#   'valence': 0.48,
#   'tempo': 151.417,
#   'type': 'audio_features',
#   'id': '4NnWuGQujzWUEg0uZokO5M',
#   'uri': 'spotify:track:4NnWuGQujzWUEg0uZokO5M',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NnWuGQujzWUEg0uZokO5M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NnWuGQujzWUEg0uZokO5M',
#   'duration_ms': 212013,
#   'time_signature': 4},
#  {'danceability': 0.411,
#   'energy': 0.986,
#   'key': 8,
#   'loudness': -2.522,
#   'mode': 0,
#   'speechiness': 0.0583,
#   'acousticness': 0.000264,
#   'instrumentalness': 0.00148,
#   'liveness': 0.371,
#   'valence': 0.649,
#   'tempo': 165.981,
#   'type': 'audio_features',
#   'id': '5BB0Jzw60KyfSTyjJqtely',
#   'uri': 'spotify:track:5BB0Jzw60KyfSTyjJqtely',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BB0Jzw60KyfSTyjJqtely',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BB0Jzw60KyfSTyjJqtely',
#   'duration_ms': 205960,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.951,
#   'key': 1,
#   'loudness': -3.754,
#   'mode': 1,
#   'speechiness': 0.0645,
#   'acousticness': 0.00038,
#   'instrumentalness': 2.39e-06,
#   'liveness': 0.261,
#   'valence': 0.442,
#   'tempo': 162.065,
#   'type': 'audio_features',
#   'id': '3agtg0x11wPvLIWkYR39nZ',
#   'uri': 'spotify:track:3agtg0x11wPvLIWkYR39nZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3agtg0x11wPvLIWkYR39nZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3agtg0x11wPvLIWkYR39nZ',
#   'duration_ms': 213933,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.894,
#   'key': 7,
#   'loudness': -6.382,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.000136,
#   'instrumentalness': 0.369,
#   'liveness': 0.286,
#   'valence': 0.566,
#   'tempo': 125.596,
#   'type': 'audio_features',
#   'id': '3GcVQCRSaPNupmf65YKyQI',
#   'uri': 'spotify:track:3GcVQCRSaPNupmf65YKyQI',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GcVQCRSaPNupmf65YKyQI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GcVQCRSaPNupmf65YKyQI',
#   'duration_ms': 185960,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.929,
#   'key': 2,
#   'loudness': -6.729,
#   'mode': 1,
#   'speechiness': 0.0701,
#   'acousticness': 0.00162,
#   'instrumentalness': 0.105,
#   'liveness': 0.0789,
#   'valence': 0.539,
#   'tempo': 127.059,
#   'type': 'audio_features',
#   'id': '1MQTmpYOZ6fcMQc56Hdo7T',
#   'uri': 'spotify:track:1MQTmpYOZ6fcMQc56Hdo7T',
#   'track_href': 'https://api.spotify.com/v1/tracks/1MQTmpYOZ6fcMQc56Hdo7T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MQTmpYOZ6fcMQc56Hdo7T',
#   'duration_ms': 205600,
#   'time_signature': 4},
#  {'danceability': 0.648,
#   'energy': 0.937,
#   'key': 2,
#   'loudness': -3.977,
#   'mode': 1,
#   'speechiness': 0.0892,
#   'acousticness': 0.000539,
#   'instrumentalness': 0,
#   'liveness': 0.0555,
#   'valence': 0.679,
#   'tempo': 91.469,
#   'type': 'audio_features',
#   'id': '0cJFobGkaiupCsOfE2eBZ1',
#   'uri': 'spotify:track:0cJFobGkaiupCsOfE2eBZ1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cJFobGkaiupCsOfE2eBZ1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cJFobGkaiupCsOfE2eBZ1',
#   'duration_ms': 196840,
#   'time_signature': 4},
#  {'danceability': 0.349,
#   'energy': 0.981,
#   'key': 2,
#   'loudness': -3.228,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 2.58e-05,
#   'instrumentalness': 0,
#   'liveness': 0.343,
#   'valence': 0.207,
#   'tempo': 160.042,
#   'type': 'audio_features',
#   'id': '4JsDHMv5PVO8N07DbDq33r',
#   'uri': 'spotify:track:4JsDHMv5PVO8N07DbDq33r',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JsDHMv5PVO8N07DbDq33r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JsDHMv5PVO8N07DbDq33r',
#   'duration_ms': 202640,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.645,
#   'key': 10,
#   'loudness': -8.535,
#   'mode': 0,
#   'speechiness': 0.318,
#   'acousticness': 0.0863,
#   'instrumentalness': 6.2e-06,
#   'liveness': 0.332,
#   'valence': 0.612,
#   'tempo': 151.307,
#   'type': 'audio_features',
#   'id': '4jU7NPkz4HVnM4hweqNhI1',
#   'uri': 'spotify:track:4jU7NPkz4HVnM4hweqNhI1',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jU7NPkz4HVnM4hweqNhI1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jU7NPkz4HVnM4hweqNhI1',
#   'duration_ms': 157560,
#   'time_signature': 4},
#  {'danceability': 0.264,
#   'energy': 0.78,
#   'key': 0,
#   'loudness': -2.741,
#   'mode': 1,
#   'speechiness': 0.0517,
#   'acousticness': 0.0452,
#   'instrumentalness': 0.0222,
#   'liveness': 0.376,
#   'valence': 0.456,
#   'tempo': 155.376,
#   'type': 'audio_features',
#   'id': '7ISL3LO8AWP3fKIXunvqTa',
#   'uri': 'spotify:track:7ISL3LO8AWP3fKIXunvqTa',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ISL3LO8AWP3fKIXunvqTa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ISL3LO8AWP3fKIXunvqTa',
#   'duration_ms': 280467,
#   'time_signature': 4},
#  {'danceability': 0.205,
#   'energy': 0.973,
#   'key': 6,
#   'loudness': -3.389,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.01,
#   'instrumentalness': 0,
#   'liveness': 0.393,
#   'valence': 0.565,
#   'tempo': 172.689,
#   'type': 'audio_features',
#   'id': '717oSBYrcR8awQgUsmyE32',
#   'uri': 'spotify:track:717oSBYrcR8awQgUsmyE32',
#   'track_href': 'https://api.spotify.com/v1/tracks/717oSBYrcR8awQgUsmyE32',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/717oSBYrcR8awQgUsmyE32',
#   'duration_ms': 114667,
#   'time_signature': 4},
#  {'danceability': 0.511,
#   'energy': 0.934,
#   'key': 3,
#   'loudness': -4.561,
#   'mode': 1,
#   'speechiness': 0.242,
#   'acousticness': 0.00403,
#   'instrumentalness': 3.48e-05,
#   'liveness': 0.242,
#   'valence': 0.668,
#   'tempo': 168.062,
#   'type': 'audio_features',
#   'id': '454I78HEySdcHE8fcVabTb',
#   'uri': 'spotify:track:454I78HEySdcHE8fcVabTb',
#   'track_href': 'https://api.spotify.com/v1/tracks/454I78HEySdcHE8fcVabTb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/454I78HEySdcHE8fcVabTb',
#   'duration_ms': 272240,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.866,
#   'key': 8,
#   'loudness': -5.785,
#   'mode': 1,
#   'speechiness': 0.0687,
#   'acousticness': 0.000702,
#   'instrumentalness': 0.778,
#   'liveness': 0.238,
#   'valence': 0.342,
#   'tempo': 149.992,
#   'type': 'audio_features',
#   'id': '5G6jZFDAFlpAA9v5LTV4NI',
#   'uri': 'spotify:track:5G6jZFDAFlpAA9v5LTV4NI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5G6jZFDAFlpAA9v5LTV4NI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5G6jZFDAFlpAA9v5LTV4NI',
#   'duration_ms': 206924,
#   'time_signature': 4},
#  {'danceability': 0.514,
#   'energy': 0.779,
#   'key': 8,
#   'loudness': -5.136,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'acousticness': 0.00314,
#   'instrumentalness': 1.3e-05,
#   'liveness': 0.0635,
#   'valence': 0.313,
#   'tempo': 91.089,
#   'type': 'audio_features',
#   'id': '0Rw35DKIumkbbMC7XPOn5r',
#   'uri': 'spotify:track:0Rw35DKIumkbbMC7XPOn5r',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Rw35DKIumkbbMC7XPOn5r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Rw35DKIumkbbMC7XPOn5r',
#   'duration_ms': 217538,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.942,
#   'key': 9,
#   'loudness': -2.206,
#   'mode': 1,
#   'speechiness': 0.0496,
#   'acousticness': 9.56e-05,
#   'instrumentalness': 0.000438,
#   'liveness': 0.209,
#   'valence': 0.5,
#   'tempo': 164.975,
#   'type': 'audio_features',
#   'id': '6GPpocnUJbzMNMTJDLYCim',
#   'uri': 'spotify:track:6GPpocnUJbzMNMTJDLYCim',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GPpocnUJbzMNMTJDLYCim',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GPpocnUJbzMNMTJDLYCim',
#   'duration_ms': 253947,
#   'time_signature': 4},
#  {'danceability': 0.424,
#   'energy': 0.919,
#   'key': 9,
#   'loudness': -4.629,
#   'mode': 1,
#   'speechiness': 0.1,
#   'acousticness': 0.00306,
#   'instrumentalness': 0.00674,
#   'liveness': 0.123,
#   'valence': 0.684,
#   'tempo': 163.732,
#   'type': 'audio_features',
#   'id': '6WlmA3HPHuNIR2mxI8LkZF',
#   'uri': 'spotify:track:6WlmA3HPHuNIR2mxI8LkZF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6WlmA3HPHuNIR2mxI8LkZF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WlmA3HPHuNIR2mxI8LkZF',
#   'duration_ms': 171467,
#   'time_signature': 4},
#  {'danceability': 0.449,
#   'energy': 0.864,
#   'key': 1,
#   'loudness': -3.892,
#   'mode': 1,
#   'speechiness': 0.0352,
#   'acousticness': 2.04e-05,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.713,
#   'tempo': 167.154,
#   'type': 'audio_features',
#   'id': '0ChpoNjXfJPjMvCIN6so6J',
#   'uri': 'spotify:track:0ChpoNjXfJPjMvCIN6so6J',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ChpoNjXfJPjMvCIN6so6J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ChpoNjXfJPjMvCIN6so6J',
#   'duration_ms': 226080,
#   'time_signature': 4},
#  {'danceability': 0.435,
#   'energy': 0.95,
#   'key': 8,
#   'loudness': -3.869,
#   'mode': 1,
#   'speechiness': 0.106,
#   'acousticness': 0.000494,
#   'instrumentalness': 0,
#   'liveness': 0.317,
#   'valence': 0.457,
#   'tempo': 160.987,
#   'type': 'audio_features',
#   'id': '6xyiHZgrmXw7sMyYXbXjPV',
#   'uri': 'spotify:track:6xyiHZgrmXw7sMyYXbXjPV',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xyiHZgrmXw7sMyYXbXjPV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xyiHZgrmXw7sMyYXbXjPV',
#   'duration_ms': 207634,
#   'time_signature': 4},
#  {'danceability': 0.439,
#   'energy': 0.945,
#   'key': 1,
#   'loudness': -2.21,
#   'mode': 1,
#   'speechiness': 0.138,
#   'acousticness': 0.00677,
#   'instrumentalness': 0,
#   'liveness': 0.166,
#   'valence': 0.455,
#   'tempo': 161.954,
#   'type': 'audio_features',
#   'id': '1eylM8qwVdD1AXDy3vjSgT',
#   'uri': 'spotify:track:1eylM8qwVdD1AXDy3vjSgT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1eylM8qwVdD1AXDy3vjSgT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1eylM8qwVdD1AXDy3vjSgT',
#   'duration_ms': 195680,
#   'time_signature': 4},
#  {'danceability': 0.466,
#   'energy': 0.951,
#   'key': 5,
#   'loudness': -3.314,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.0016,
#   'instrumentalness': 0.00242,
#   'liveness': 0.351,
#   'valence': 0.499,
#   'tempo': 165.107,
#   'type': 'audio_features',
#   'id': '5NAiPIEzxAexFE3ucV18Q8',
#   'uri': 'spotify:track:5NAiPIEzxAexFE3ucV18Q8',
#   'track_href': 'https://api.spotify.com/v1/tracks/5NAiPIEzxAexFE3ucV18Q8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NAiPIEzxAexFE3ucV18Q8',
#   'duration_ms': 222147,
#   'time_signature': 4},
#  {'danceability': 0.462,
#   'energy': 0.979,
#   'key': 1,
#   'loudness': -4.255,
#   'mode': 0,
#   'speechiness': 0.0664,
#   'acousticness': 0.000899,
#   'instrumentalness': 8.3e-06,
#   'liveness': 0.33,
#   'valence': 0.542,
#   'tempo': 173.957,
#   'type': 'audio_features',
#   'id': '0xfMFT9G8Ekk7CEYtVabIm',
#   'uri': 'spotify:track:0xfMFT9G8Ekk7CEYtVabIm',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xfMFT9G8Ekk7CEYtVabIm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xfMFT9G8Ekk7CEYtVabIm',
#   'duration_ms': 171323,
#   'time_signature': 4},
#  {'danceability': 0.465,
#   'energy': 0.963,
#   'key': 0,
#   'loudness': -3.568,
#   'mode': 0,
#   'speechiness': 0.0484,
#   'acousticness': 0.00161,
#   'instrumentalness': 0,
#   'liveness': 0.196,
#   'valence': 0.528,
#   'tempo': 160.065,
#   'type': 'audio_features',
#   'id': '6Y2kW1mdHE0znPCjtOdt5m',
#   'uri': 'spotify:track:6Y2kW1mdHE0znPCjtOdt5m',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Y2kW1mdHE0znPCjtOdt5m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Y2kW1mdHE0znPCjtOdt5m',
#   'duration_ms': 230027,
#   'time_signature': 4},
#  {'danceability': 0.361,
#   'energy': 0.962,
#   'key': 1,
#   'loudness': -2.943,
#   'mode': 1,
#   'speechiness': 0.0661,
#   'acousticness': 0.0103,
#   'instrumentalness': 0.00101,
#   'liveness': 0.448,
#   'valence': 0.927,
#   'tempo': 161.3,
#   'type': 'audio_features',
#   'id': '6Td8HRLhdV39kKdOQpfQum',
#   'uri': 'spotify:track:6Td8HRLhdV39kKdOQpfQum',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Td8HRLhdV39kKdOQpfQum',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Td8HRLhdV39kKdOQpfQum',
#   'duration_ms': 174027,
#   'time_signature': 4},
#  {'danceability': 0.567,
#   'energy': 0.517,
#   'key': 8,
#   'loudness': -7.548,
#   'mode': 1,
#   'speechiness': 0.0708,
#   'acousticness': 0.000292,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.627,
#   'tempo': 179.959,
#   'type': 'audio_features',
#   'id': '2eXSPTZmhkXRGob1hsFdVd',
#   'uri': 'spotify:track:2eXSPTZmhkXRGob1hsFdVd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eXSPTZmhkXRGob1hsFdVd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eXSPTZmhkXRGob1hsFdVd',
#   'duration_ms': 177221,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.966,
#   'key': 0,
#   'loudness': -3.876,
#   'mode': 1,
#   'speechiness': 0.0946,
#   'acousticness': 0.00575,
#   'instrumentalness': 1.56e-06,
#   'liveness': 0.117,
#   'valence': 0.638,
#   'tempo': 159.948,
#   'type': 'audio_features',
#   'id': '44TuSOP6xIAEeJmZsN3nXO',
#   'uri': 'spotify:track:44TuSOP6xIAEeJmZsN3nXO',
#   'track_href': 'https://api.spotify.com/v1/tracks/44TuSOP6xIAEeJmZsN3nXO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44TuSOP6xIAEeJmZsN3nXO',
#   'duration_ms': 235613,
#   'time_signature': 4},
#  {'danceability': 0.475,
#   'energy': 0.958,
#   'key': 2,
#   'loudness': -3.322,
#   'mode': 0,
#   'speechiness': 0.0581,
#   'acousticness': 0.000277,
#   'instrumentalness': 2.2e-06,
#   'liveness': 0.432,
#   'valence': 0.624,
#   'tempo': 169.16,
#   'type': 'audio_features',
#   'id': '2Ll44WxlG2eiqL6NtEnf8M',
#   'uri': 'spotify:track:2Ll44WxlG2eiqL6NtEnf8M',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Ll44WxlG2eiqL6NtEnf8M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Ll44WxlG2eiqL6NtEnf8M',
#   'duration_ms': 213867,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.915,
#   'key': 9,
#   'loudness': -4.948,
#   'mode': 1,
#   'speechiness': 0.0891,
#   'acousticness': 0.000355,
#   'instrumentalness': 0.00701,
#   'liveness': 0.231,
#   'valence': 0.941,
#   'tempo': 168.965,
#   'type': 'audio_features',
#   'id': '5unvfecPlWyn1NkFpf5YvA',
#   'uri': 'spotify:track:5unvfecPlWyn1NkFpf5YvA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5unvfecPlWyn1NkFpf5YvA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5unvfecPlWyn1NkFpf5YvA',
#   'duration_ms': 144391,
#   'time_signature': 4},
#  {'danceability': 0.4,
#   'energy': 0.946,
#   'key': 1,
#   'loudness': -3.966,
#   'mode': 0,
#   'speechiness': 0.0634,
#   'acousticness': 0.000136,
#   'instrumentalness': 0.853,
#   'liveness': 0.155,
#   'valence': 0.611,
#   'tempo': 161.591,
#   'type': 'audio_features',
#   'id': '2mwnYvlLVP465u9V9wjUGj',
#   'uri': 'spotify:track:2mwnYvlLVP465u9V9wjUGj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mwnYvlLVP465u9V9wjUGj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mwnYvlLVP465u9V9wjUGj',
#   'duration_ms': 245573,
#   'time_signature': 4},
#  {'danceability': 0.522,
#   'energy': 0.88,
#   'key': 5,
#   'loudness': -4.104,
#   'mode': 0,
#   'speechiness': 0.0633,
#   'acousticness': 9.38e-05,
#   'instrumentalness': 0.00111,
#   'liveness': 0.0812,
#   'valence': 0.701,
#   'tempo': 174.762,
#   'type': 'audio_features',
#   'id': '0arNrzPygksLY2pEbRgBjw',
#   'uri': 'spotify:track:0arNrzPygksLY2pEbRgBjw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0arNrzPygksLY2pEbRgBjw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0arNrzPygksLY2pEbRgBjw',
#   'duration_ms': 219267,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.974,
#   'key': 1,
#   'loudness': -4.706,
#   'mode': 1,
#   'speechiness': 0.191,
#   'acousticness': 8.15e-05,
#   'instrumentalness': 0.00155,
#   'liveness': 0.0871,
#   'valence': 0.463,
#   'tempo': 165.182,
#   'type': 'audio_features',
#   'id': '7f9I5WdyXm5q1XqnSYgQZb',
#   'uri': 'spotify:track:7f9I5WdyXm5q1XqnSYgQZb',
#   'track_href': 'https://api.spotify.com/v1/tracks/7f9I5WdyXm5q1XqnSYgQZb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7f9I5WdyXm5q1XqnSYgQZb',
#   'duration_ms': 172867,
#   'time_signature': 4},
#  {'danceability': 0.361,
#   'energy': 0.916,
#   'key': 8,
#   'loudness': -6.248,
#   'mode': 0,
#   'speechiness': 0.0771,
#   'acousticness': 0.000129,
#   'instrumentalness': 0.0129,
#   'liveness': 0.206,
#   'valence': 0.643,
#   'tempo': 173.407,
#   'type': 'audio_features',
#   'id': '5jVKpqA8ARnVuMmt8yTyGi',
#   'uri': 'spotify:track:5jVKpqA8ARnVuMmt8yTyGi',
#   'track_href': 'https://api.spotify.com/v1/tracks/5jVKpqA8ARnVuMmt8yTyGi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jVKpqA8ARnVuMmt8yTyGi',
#   'duration_ms': 199187,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.925,
#   'key': 8,
#   'loudness': -3.787,
#   'mode': 1,
#   'speechiness': 0.0717,
#   'acousticness': 0.00195,
#   'instrumentalness': 0.000315,
#   'liveness': 0.302,
#   'valence': 0.577,
#   'tempo': 160.959,
#   'type': 'audio_features',
#   'id': '4hui0bX1Bv89yg1BTsz4NU',
#   'uri': 'spotify:track:4hui0bX1Bv89yg1BTsz4NU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4hui0bX1Bv89yg1BTsz4NU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4hui0bX1Bv89yg1BTsz4NU',
#   'duration_ms': 332413,
#   'time_signature': 4},
#  {'danceability': 0.381,
#   'energy': 0.961,
#   'key': 1,
#   'loudness': -3.614,
#   'mode': 1,
#   'speechiness': 0.0869,
#   'acousticness': 0.000949,
#   'instrumentalness': 0.000294,
#   'liveness': 0.0531,
#   'valence': 0.787,
#   'tempo': 156.062,
#   'type': 'audio_features',
#   'id': '4GMCZUi6cVQJ5wPWwJ36rW',
#   'uri': 'spotify:track:4GMCZUi6cVQJ5wPWwJ36rW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4GMCZUi6cVQJ5wPWwJ36rW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GMCZUi6cVQJ5wPWwJ36rW',
#   'duration_ms': 143080,
#   'time_signature': 4},
#  {'danceability': 0.411,
#   'energy': 0.967,
#   'key': 9,
#   'loudness': -2.28,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.000286,
#   'instrumentalness': 0,
#   'liveness': 0.0925,
#   'valence': 0.444,
#   'tempo': 170.913,
#   'type': 'audio_features',
#   'id': '5z7S8ITmKjMG9BztxgCf2s',
#   'uri': 'spotify:track:5z7S8ITmKjMG9BztxgCf2s',
#   'track_href': 'https://api.spotify.com/v1/tracks/5z7S8ITmKjMG9BztxgCf2s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5z7S8ITmKjMG9BztxgCf2s',
#   'duration_ms': 192787,
#   'time_signature': 4},
#  {'danceability': 0.381,
#   'energy': 0.838,
#   'key': 6,
#   'loudness': -6.562,
#   'mode': 0,
#   'speechiness': 0.0709,
#   'acousticness': 0.0046,
#   'instrumentalness': 3.77e-05,
#   'liveness': 0.101,
#   'valence': 0.581,
#   'tempo': 118.214,
#   'type': 'audio_features',
#   'id': '3T76zPJz3tWL27FrjJe2ot',
#   'uri': 'spotify:track:3T76zPJz3tWL27FrjJe2ot',
#   'track_href': 'https://api.spotify.com/v1/tracks/3T76zPJz3tWL27FrjJe2ot',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3T76zPJz3tWL27FrjJe2ot',
#   'duration_ms': 219400,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.913,
#   'key': 4,
#   'loudness': -3.286,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.675,
#   'tempo': 165.986,
#   'type': 'audio_features',
#   'id': '1SeefzwSDiFCjRWaBslRIj',
#   'uri': 'spotify:track:1SeefzwSDiFCjRWaBslRIj',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SeefzwSDiFCjRWaBslRIj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SeefzwSDiFCjRWaBslRIj',
#   'duration_ms': 189418,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.855,
#   'key': 8,
#   'loudness': -3.232,
#   'mode': 0,
#   'speechiness': 0.29,
#   'acousticness': 0.00354,
#   'instrumentalness': 0,
#   'liveness': 0.372,
#   'valence': 0.65,
#   'tempo': 185.791,
#   'type': 'audio_features',
#   'id': '6spaGIZEfeDYlgAupMI34k',
#   'uri': 'spotify:track:6spaGIZEfeDYlgAupMI34k',
#   'track_href': 'https://api.spotify.com/v1/tracks/6spaGIZEfeDYlgAupMI34k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6spaGIZEfeDYlgAupMI34k',
#   'duration_ms': 178116,
#   'time_signature': 4},
#  {'danceability': 0.342,
#   'energy': 0.992,
#   'key': 11,
#   'loudness': -3.251,
#   'mode': 0,
#   'speechiness': 0.0632,
#   'acousticness': 0.019,
#   'instrumentalness': 0.00604,
#   'liveness': 0.101,
#   'valence': 0.938,
#   'tempo': 165.23,
#   'type': 'audio_features',
#   'id': '5F7AoCwgftgUdGUgd57RVE',
#   'uri': 'spotify:track:5F7AoCwgftgUdGUgd57RVE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5F7AoCwgftgUdGUgd57RVE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5F7AoCwgftgUdGUgd57RVE',
#   'duration_ms': 120507,
#   'time_signature': 4},
#  {'danceability': 0.187,
#   'energy': 0.855,
#   'key': 11,
#   'loudness': -4.316,
#   'mode': 0,
#   'speechiness': 0.0624,
#   'acousticness': 0.000531,
#   'instrumentalness': 0.0204,
#   'liveness': 0.361,
#   'valence': 0.257,
#   'tempo': 160.892,
#   'type': 'audio_features',
#   'id': '0MHHAIjPAd3OSfBS3H0fPg',
#   'uri': 'spotify:track:0MHHAIjPAd3OSfBS3H0fPg',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MHHAIjPAd3OSfBS3H0fPg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MHHAIjPAd3OSfBS3H0fPg',
#   'duration_ms': 235400,
#   'time_signature': 3},
#  {'danceability': 0.509,
#   'energy': 0.817,
#   'key': 10,
#   'loudness': -5.472,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.000439,
#   'instrumentalness': 5.56e-06,
#   'liveness': 0.0947,
#   'valence': 0.597,
#   'tempo': 155.199,
#   'type': 'audio_features',
#   'id': '5dJqHtAc4toOPTRX9xfOB6',
#   'uri': 'spotify:track:5dJqHtAc4toOPTRX9xfOB6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dJqHtAc4toOPTRX9xfOB6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dJqHtAc4toOPTRX9xfOB6',
#   'duration_ms': 237573,
#   'time_signature': 4},
#  {'danceability': 0.409,
#   'energy': 0.969,
#   'key': 1,
#   'loudness': -2.423,
#   'mode': 0,
#   'speechiness': 0.0706,
#   'acousticness': 0.00435,
#   'instrumentalness': 0.000124,
#   'liveness': 0.0602,
#   'valence': 0.5,
#   'tempo': 166.02,
#   'type': 'audio_features',
#   'id': '63JU4kHsgytIKkSM4tedme',
#   'uri': 'spotify:track:63JU4kHsgytIKkSM4tedme',
#   'track_href': 'https://api.spotify.com/v1/tracks/63JU4kHsgytIKkSM4tedme',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63JU4kHsgytIKkSM4tedme',
#   'duration_ms': 216860,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.948,
#   'key': 7,
#   'loudness': -3.841,
#   'mode': 1,
#   'speechiness': 0.0596,
#   'acousticness': 1.9e-05,
#   'instrumentalness': 0.144,
#   'liveness': 0.196,
#   'valence': 0.642,
#   'tempo': 117.998,
#   'type': 'audio_features',
#   'id': '69uzV9BQmNLPIu0dWK4Tbe',
#   'uri': 'spotify:track:69uzV9BQmNLPIu0dWK4Tbe',
#   'track_href': 'https://api.spotify.com/v1/tracks/69uzV9BQmNLPIu0dWK4Tbe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/69uzV9BQmNLPIu0dWK4Tbe',
#   'duration_ms': 133353,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.832,
#   'key': 4,
#   'loudness': -5.96,
#   'mode': 0,
#   'speechiness': 0.0323,
#   'acousticness': 0.00967,
#   'instrumentalness': 2.94e-05,
#   'liveness': 0.132,
#   'valence': 0.3,
#   'tempo': 155.061,
#   'type': 'audio_features',
#   'id': '5g9I9uYUcbvtkAuZXjqGfP',
#   'uri': 'spotify:track:5g9I9uYUcbvtkAuZXjqGfP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5g9I9uYUcbvtkAuZXjqGfP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5g9I9uYUcbvtkAuZXjqGfP',
#   'duration_ms': 161592,
#   'time_signature': 4},
#  {'danceability': 0.328,
#   'energy': 0.904,
#   'key': 3,
#   'loudness': -5.063,
#   'mode': 0,
#   'speechiness': 0.0455,
#   'acousticness': 4.31e-05,
#   'instrumentalness': 0.064,
#   'liveness': 0.11,
#   'valence': 0.516,
#   'tempo': 186.253,
#   'type': 'audio_features',
#   'id': '2yYASbXnAV71CLbNY1HCWf',
#   'uri': 'spotify:track:2yYASbXnAV71CLbNY1HCWf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2yYASbXnAV71CLbNY1HCWf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2yYASbXnAV71CLbNY1HCWf',
#   'duration_ms': 190573,
#   'time_signature': 4},
#  {'danceability': 0.326,
#   'energy': 0.894,
#   'key': 9,
#   'loudness': -9.558,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.00035,
#   'instrumentalness': 0,
#   'liveness': 0.435,
#   'valence': 0.664,
#   'tempo': 165.193,
#   'type': 'audio_features',
#   'id': '0KEhlgtlk0HuqBIqfGCGdF',
#   'uri': 'spotify:track:0KEhlgtlk0HuqBIqfGCGdF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KEhlgtlk0HuqBIqfGCGdF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KEhlgtlk0HuqBIqfGCGdF',
#   'duration_ms': 227200,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.981,
#   'key': 2,
#   'loudness': -2.75,
#   'mode': 1,
#   'speechiness': 0.0906,
#   'acousticness': 0.000867,
#   'instrumentalness': 0.00177,
#   'liveness': 0.197,
#   'valence': 0.633,
#   'tempo': 158.937,
#   'type': 'audio_features',
#   'id': '1INksmStBpxdNlBzwGUvsg',
#   'uri': 'spotify:track:1INksmStBpxdNlBzwGUvsg',
#   'track_href': 'https://api.spotify.com/v1/tracks/1INksmStBpxdNlBzwGUvsg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1INksmStBpxdNlBzwGUvsg',
#   'duration_ms': 240572,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.919,
#   'key': 1,
#   'loudness': -5.109,
#   'mode': 0,
#   'speechiness': 0.0831,
#   'acousticness': 0.00338,
#   'instrumentalness': 0.000386,
#   'liveness': 0.337,
#   'valence': 0.532,
#   'tempo': 129.955,
#   'type': 'audio_features',
#   'id': '7jKziCSFvitg68mOsTd7RL',
#   'uri': 'spotify:track:7jKziCSFvitg68mOsTd7RL',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jKziCSFvitg68mOsTd7RL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jKziCSFvitg68mOsTd7RL',
#   'duration_ms': 210133,
#   'time_signature': 4},
#  {'danceability': 0.384,
#   'energy': 0.921,
#   'key': 5,
#   'loudness': -3.609,
#   'mode': 0,
#   'speechiness': 0.0489,
#   'acousticness': 0.0125,
#   'instrumentalness': 0.108,
#   'liveness': 0.152,
#   'valence': 0.446,
#   'tempo': 171.036,
#   'type': 'audio_features',
#   'id': '3SevJWsbqUOpfPOpRZGrP9',
#   'uri': 'spotify:track:3SevJWsbqUOpfPOpRZGrP9',
#   'track_href': 'https://api.spotify.com/v1/tracks/3SevJWsbqUOpfPOpRZGrP9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SevJWsbqUOpfPOpRZGrP9',
#   'duration_ms': 225787,
#   'time_signature': 4},
#  {'danceability': 0.343,
#   'energy': 0.961,
#   'key': 11,
#   'loudness': -2.271,
#   'mode': 1,
#   'speechiness': 0.0688,
#   'acousticness': 0.00187,
#   'instrumentalness': 2.7e-06,
#   'liveness': 0.236,
#   'valence': 0.449,
#   'tempo': 166.983,
#   'type': 'audio_features',
#   'id': '70nKt5OKAbXwlRrKsrf1oq',
#   'uri': 'spotify:track:70nKt5OKAbXwlRrKsrf1oq',
#   'track_href': 'https://api.spotify.com/v1/tracks/70nKt5OKAbXwlRrKsrf1oq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70nKt5OKAbXwlRrKsrf1oq',
#   'duration_ms': 201557,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.985,
#   'key': 4,
#   'loudness': -3.358,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.000687,
#   'instrumentalness': 0,
#   'liveness': 0.403,
#   'valence': 0.327,
#   'tempo': 100.223,
#   'type': 'audio_features',
#   'id': '3WsgkhWH001sMkbZVcjreS',
#   'uri': 'spotify:track:3WsgkhWH001sMkbZVcjreS',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WsgkhWH001sMkbZVcjreS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WsgkhWH001sMkbZVcjreS',
#   'duration_ms': 193107,
#   'time_signature': 4},
#  {'danceability': 0.312,
#   'energy': 0.975,
#   'key': 8,
#   'loudness': -4.628,
#   'mode': 1,
#   'speechiness': 0.0853,
#   'acousticness': 0.000667,
#   'instrumentalness': 1.15e-06,
#   'liveness': 0.133,
#   'valence': 0.37,
#   'tempo': 178.117,
#   'type': 'audio_features',
#   'id': '5LQN7c99Q8gvmh6xJcTZgj',
#   'uri': 'spotify:track:5LQN7c99Q8gvmh6xJcTZgj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LQN7c99Q8gvmh6xJcTZgj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LQN7c99Q8gvmh6xJcTZgj',
#   'duration_ms': 207547,
#   'time_signature': 4}]

# %%
import pandas as pd
#df=pd.DataFrame(list_of_audio_features)
#df

# %%
 # extracting the audio features of a track
list_of_audio_features = []
list_of_audio_features.append(sp.audio_features(tracks['items'][0]["track"]["id"]))

# %%
list_of_audio_features=[]
for item in range(0,75):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks['items'][item]["track"]["id"])[0])

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.847,
#   'energy': 0.69,
#   'key': 1,
#   'loudness': -7.877,
#   'mode': 0,
#   'speechiness': 0.0493,
#   'acousticness': 0.0127,
#   'instrumentalness': 6e-05,
#   'liveness': 0.0526,
#   'valence': 0.692,
#   'tempo': 125.004,
#   'type': 'audio_features',
#   'id': '4zN21mbAuaD0WqtmaTZZeP',
#   'uri': 'spotify:track:4zN21mbAuaD0WqtmaTZZeP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zN21mbAuaD0WqtmaTZZeP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zN21mbAuaD0WqtmaTZZeP',
#   'duration_ms': 186662,
#   'time_signature': 4},
#  {'danceability': 0.874,
#   'energy': 0.869,
#   'key': 1,
#   'loudness': -5.996,
#   'mode': 0,
#   'speechiness': 0.0315,
#   'acousticness': 0.00116,
#   'instrumentalness': 0.00238,
#   'liveness': 0.164,
#   'valence': 0.726,
#   'tempo': 126.027,
#   'type': 'audio_features',
#   'id': '5ZduaRci3iNUiDfJbBfAaf',
#   'uri': 'spotify:track:5ZduaRci3iNUiDfJbBfAaf',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZduaRci3iNUiDfJbBfAaf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZduaRci3iNUiDfJbBfAaf',
#   'duration_ms': 102861,
#   'time_signature': 4},
#  {'danceability': 0.848,
#   'energy': 0.821,
#   'key': 2,
#   'loudness': -5.408,
#   'mode': 0,
#   'speechiness': 0.0527,
#   'acousticness': 0.0169,
#   'instrumentalness': 0.000403,
#   'liveness': 0.0962,
#   'valence': 0.249,
#   'tempo': 125.051,
#   'type': 'audio_features',
#   'id': '6GomT970rCOkKAyyrwJeZi',
#   'uri': 'spotify:track:6GomT970rCOkKAyyrwJeZi',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GomT970rCOkKAyyrwJeZi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GomT970rCOkKAyyrwJeZi',
#   'duration_ms': 157445,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.832,
#   'key': 9,
#   'loudness': -6.432,
#   'mode': 0,
#   'speechiness': 0.0363,
#   'acousticness': 0.00953,
#   'instrumentalness': 0.00541,
#   'liveness': 0.546,
#   'valence': 0.0818,
#   'tempo': 126.0,
#   'type': 'audio_features',
#   'id': '4qDpLaFGf5ampf2DXD2TMA',
#   'uri': 'spotify:track:4qDpLaFGf5ampf2DXD2TMA',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qDpLaFGf5ampf2DXD2TMA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qDpLaFGf5ampf2DXD2TMA',
#   'duration_ms': 236000,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.932,
#   'key': 8,
#   'loudness': -10.402,
#   'mode': 1,
#   'speechiness': 0.0513,
#   'acousticness': 0.0389,
#   'instrumentalness': 0.605,
#   'liveness': 0.0615,
#   'valence': 0.553,
#   'tempo': 125.002,
#   'type': 'audio_features',
#   'id': '0w7JPlp7eEQI2EKW3ayXrv',
#   'uri': 'spotify:track:0w7JPlp7eEQI2EKW3ayXrv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0w7JPlp7eEQI2EKW3ayXrv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0w7JPlp7eEQI2EKW3ayXrv',
#   'duration_ms': 235786,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.559,
#   'key': 6,
#   'loudness': -12.876,
#   'mode': 0,
#   'speechiness': 0.0391,
#   'acousticness': 0.136,
#   'instrumentalness': 0.0894,
#   'liveness': 0.108,
#   'valence': 0.296,
#   'tempo': 145.007,
#   'type': 'audio_features',
#   'id': '4tRhRLBxIZ34Iw0eCuiC03',
#   'uri': 'spotify:track:4tRhRLBxIZ34Iw0eCuiC03',
#   'track_href': 'https://api.spotify.com/v1/tracks/4tRhRLBxIZ34Iw0eCuiC03',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tRhRLBxIZ34Iw0eCuiC03',
#   'duration_ms': 206385,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.928,
#   'key': 6,
#   'loudness': -5.812,
#   'mode': 0,
#   'speechiness': 0.0371,
#   'acousticness': 0.087,
#   'instrumentalness': 0.894,
#   'liveness': 0.332,
#   'valence': 0.182,
#   'tempo': 125.988,
#   'type': 'audio_features',
#   'id': '7jrMFjEq0t09f7m3HnnWXl',
#   'uri': 'spotify:track:7jrMFjEq0t09f7m3HnnWXl',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jrMFjEq0t09f7m3HnnWXl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jrMFjEq0t09f7m3HnnWXl',
#   'duration_ms': 171429,
#   'time_signature': 4},
#  {'danceability': 0.767,
#   'energy': 0.83,
#   'key': 7,
#   'loudness': -8.78,
#   'mode': 1,
#   'speechiness': 0.206,
#   'acousticness': 0.209,
#   'instrumentalness': 0.836,
#   'liveness': 0.0582,
#   'valence': 0.187,
#   'tempo': 75.023,
#   'type': 'audio_features',
#   'id': '3AjSfp5FDvwtMU9XBsbS8j',
#   'uri': 'spotify:track:3AjSfp5FDvwtMU9XBsbS8j',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AjSfp5FDvwtMU9XBsbS8j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AjSfp5FDvwtMU9XBsbS8j',
#   'duration_ms': 139300,
#   'time_signature': 4},
#  {'danceability': 0.847,
#   'energy': 0.724,
#   'key': 2,
#   'loudness': -7.668,
#   'mode': 1,
#   'speechiness': 0.047,
#   'acousticness': 0.00355,
#   'instrumentalness': 0.00339,
#   'liveness': 0.0731,
#   'valence': 0.326,
#   'tempo': 126.983,
#   'type': 'audio_features',
#   'id': '4zlbKky2yA657Sk5rekZoR',
#   'uri': 'spotify:track:4zlbKky2yA657Sk5rekZoR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zlbKky2yA657Sk5rekZoR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zlbKky2yA657Sk5rekZoR',
#   'duration_ms': 319964,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.889,
#   'key': 8,
#   'loudness': -6.545,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.189,
#   'instrumentalness': 0.653,
#   'liveness': 0.13,
#   'valence': 0.876,
#   'tempo': 147.983,
#   'type': 'audio_features',
#   'id': '7jQkiAaa4XYYsPH3rcfcWo',
#   'uri': 'spotify:track:7jQkiAaa4XYYsPH3rcfcWo',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jQkiAaa4XYYsPH3rcfcWo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jQkiAaa4XYYsPH3rcfcWo',
#   'duration_ms': 163515,
#   'time_signature': 4},
#  {'danceability': 0.708,
#   'energy': 0.909,
#   'key': 5,
#   'loudness': -5.999,
#   'mode': 0,
#   'speechiness': 0.0476,
#   'acousticness': 0.0324,
#   'instrumentalness': 0.527,
#   'liveness': 0.08,
#   'valence': 0.351,
#   'tempo': 127.997,
#   'type': 'audio_features',
#   'id': '5IFSvSEeCAvvBEQ85poqKB',
#   'uri': 'spotify:track:5IFSvSEeCAvvBEQ85poqKB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IFSvSEeCAvvBEQ85poqKB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IFSvSEeCAvvBEQ85poqKB',
#   'duration_ms': 164043,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.902,
#   'key': 6,
#   'loudness': -5.261,
#   'mode': 0,
#   'speechiness': 0.0624,
#   'acousticness': 0.268,
#   'instrumentalness': 0.692,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 143.011,
#   'type': 'audio_features',
#   'id': '5iKzJujKsuWtQcZ1JqrRIH',
#   'uri': 'spotify:track:5iKzJujKsuWtQcZ1JqrRIH',
#   'track_href': 'https://api.spotify.com/v1/tracks/5iKzJujKsuWtQcZ1JqrRIH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5iKzJujKsuWtQcZ1JqrRIH',
#   'duration_ms': 191329,
#   'time_signature': 4},
#  {'danceability': 0.828,
#   'energy': 0.893,
#   'key': 1,
#   'loudness': -3.344,
#   'mode': 1,
#   'speechiness': 0.0496,
#   'acousticness': 0.033,
#   'instrumentalness': 0.00535,
#   'liveness': 0.0811,
#   'valence': 0.602,
#   'tempo': 124.043,
#   'type': 'audio_features',
#   'id': '5bZjb7xKqLqa58QiUBcVvl',
#   'uri': 'spotify:track:5bZjb7xKqLqa58QiUBcVvl',
#   'track_href': 'https://api.spotify.com/v1/tracks/5bZjb7xKqLqa58QiUBcVvl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bZjb7xKqLqa58QiUBcVvl',
#   'duration_ms': 145766,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.911,
#   'key': 9,
#   'loudness': -4.977,
#   'mode': 1,
#   'speechiness': 0.144,
#   'acousticness': 0.00552,
#   'instrumentalness': 0.0247,
#   'liveness': 0.285,
#   'valence': 0.351,
#   'tempo': 128.02,
#   'type': 'audio_features',
#   'id': '4ASOMWcJUrwEpjJy4GEijz',
#   'uri': 'spotify:track:4ASOMWcJUrwEpjJy4GEijz',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ASOMWcJUrwEpjJy4GEijz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ASOMWcJUrwEpjJy4GEijz',
#   'duration_ms': 196900,
#   'time_signature': 4},
#  {'danceability': 0.889,
#   'energy': 0.871,
#   'key': 11,
#   'loudness': -5.349,
#   'mode': 0,
#   'speechiness': 0.149,
#   'acousticness': 0.00176,
#   'instrumentalness': 0.586,
#   'liveness': 0.279,
#   'valence': 0.491,
#   'tempo': 124.008,
#   'type': 'audio_features',
#   'id': '2UwgoIMAYT0pDOxUFTjEVJ',
#   'uri': 'spotify:track:2UwgoIMAYT0pDOxUFTjEVJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UwgoIMAYT0pDOxUFTjEVJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UwgoIMAYT0pDOxUFTjEVJ',
#   'duration_ms': 178909,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.791,
#   'key': 1,
#   'loudness': -7.352,
#   'mode': 1,
#   'speechiness': 0.215,
#   'acousticness': 0.0454,
#   'instrumentalness': 0.0185,
#   'liveness': 0.0354,
#   'valence': 0.383,
#   'tempo': 138.032,
#   'type': 'audio_features',
#   'id': '04R4oiYD4NU6ZkdwlaJSep',
#   'uri': 'spotify:track:04R4oiYD4NU6ZkdwlaJSep',
#   'track_href': 'https://api.spotify.com/v1/tracks/04R4oiYD4NU6ZkdwlaJSep',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04R4oiYD4NU6ZkdwlaJSep',
#   'duration_ms': 149565,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.869,
#   'key': 7,
#   'loudness': -5.159,
#   'mode': 0,
#   'speechiness': 0.0945,
#   'acousticness': 0.00083,
#   'instrumentalness': 0.000653,
#   'liveness': 0.375,
#   'valence': 0.681,
#   'tempo': 124.007,
#   'type': 'audio_features',
#   'id': '15223sfwoQj4IAJL8GSnfO',
#   'uri': 'spotify:track:15223sfwoQj4IAJL8GSnfO',
#   'track_href': 'https://api.spotify.com/v1/tracks/15223sfwoQj4IAJL8GSnfO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15223sfwoQj4IAJL8GSnfO',
#   'duration_ms': 183810,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.859,
#   'key': 6,
#   'loudness': -6.19,
#   'mode': 1,
#   'speechiness': 0.0542,
#   'acousticness': 0.0112,
#   'instrumentalness': 0.423,
#   'liveness': 0.0831,
#   'valence': 0.4,
#   'tempo': 125.969,
#   'type': 'audio_features',
#   'id': '0NNSpmyyr0I4lrMaXS8Tba',
#   'uri': 'spotify:track:0NNSpmyyr0I4lrMaXS8Tba',
#   'track_href': 'https://api.spotify.com/v1/tracks/0NNSpmyyr0I4lrMaXS8Tba',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NNSpmyyr0I4lrMaXS8Tba',
#   'duration_ms': 154286,
#   'time_signature': 4},
#  {'danceability': 0.925,
#   'energy': 0.561,
#   'key': 3,
#   'loudness': -8.675,
#   'mode': 1,
#   'speechiness': 0.176,
#   'acousticness': 0.0659,
#   'instrumentalness': 0.0271,
#   'liveness': 0.152,
#   'valence': 0.721,
#   'tempo': 128.034,
#   'type': 'audio_features',
#   'id': '59QDyqLww2pxyg9ijOPO7f',
#   'uri': 'spotify:track:59QDyqLww2pxyg9ijOPO7f',
#   'track_href': 'https://api.spotify.com/v1/tracks/59QDyqLww2pxyg9ijOPO7f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59QDyqLww2pxyg9ijOPO7f',
#   'duration_ms': 181365,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.933,
#   'key': 0,
#   'loudness': -2.855,
#   'mode': 1,
#   'speechiness': 0.104,
#   'acousticness': 0.0221,
#   'instrumentalness': 0.00504,
#   'liveness': 0.266,
#   'valence': 0.46,
#   'tempo': 128.036,
#   'type': 'audio_features',
#   'id': '19bua05ITWjFrk9iGxOA7r',
#   'uri': 'spotify:track:19bua05ITWjFrk9iGxOA7r',
#   'track_href': 'https://api.spotify.com/v1/tracks/19bua05ITWjFrk9iGxOA7r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19bua05ITWjFrk9iGxOA7r',
#   'duration_ms': 170578,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.63,
#   'key': 2,
#   'loudness': -7.003,
#   'mode': 1,
#   'speechiness': 0.0413,
#   'acousticness': 0.00879,
#   'instrumentalness': 0.147,
#   'liveness': 0.058,
#   'valence': 0.216,
#   'tempo': 125.0,
#   'type': 'audio_features',
#   'id': '48Jf12YHPBCAfAzi255Rvr',
#   'uri': 'spotify:track:48Jf12YHPBCAfAzi255Rvr',
#   'track_href': 'https://api.spotify.com/v1/tracks/48Jf12YHPBCAfAzi255Rvr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48Jf12YHPBCAfAzi255Rvr',
#   'duration_ms': 242880,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.94,
#   'key': 10,
#   'loudness': -6.097,
#   'mode': 1,
#   'speechiness': 0.0617,
#   'acousticness': 0.00124,
#   'instrumentalness': 0.269,
#   'liveness': 0.15,
#   'valence': 0.238,
#   'tempo': 128.001,
#   'type': 'audio_features',
#   'id': '6txvQu0zUbiqG24A8XMLnK',
#   'uri': 'spotify:track:6txvQu0zUbiqG24A8XMLnK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6txvQu0zUbiqG24A8XMLnK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6txvQu0zUbiqG24A8XMLnK',
#   'duration_ms': 188592,
#   'time_signature': 4},
#  {'danceability': 0.941,
#   'energy': 0.753,
#   'key': 6,
#   'loudness': -4.905,
#   'mode': 1,
#   'speechiness': 0.0905,
#   'acousticness': 0.458,
#   'instrumentalness': 0.61,
#   'liveness': 0.109,
#   'valence': 0.681,
#   'tempo': 127.02,
#   'type': 'audio_features',
#   'id': '1635wWSdp29PO3GxYhy991',
#   'uri': 'spotify:track:1635wWSdp29PO3GxYhy991',
#   'track_href': 'https://api.spotify.com/v1/tracks/1635wWSdp29PO3GxYhy991',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1635wWSdp29PO3GxYhy991',
#   'duration_ms': 169606,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.968,
#   'key': 8,
#   'loudness': -5.282,
#   'mode': 1,
#   'speechiness': 0.0423,
#   'acousticness': 0.0012,
#   'instrumentalness': 0.758,
#   'liveness': 0.103,
#   'valence': 0.782,
#   'tempo': 126.008,
#   'type': 'audio_features',
#   'id': '5hMlz6wuVF3gqwMGu1iDTg',
#   'uri': 'spotify:track:5hMlz6wuVF3gqwMGu1iDTg',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hMlz6wuVF3gqwMGu1iDTg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hMlz6wuVF3gqwMGu1iDTg',
#   'duration_ms': 194311,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.978,
#   'key': 9,
#   'loudness': -4.495,
#   'mode': 0,
#   'speechiness': 0.0595,
#   'acousticness': 0.00147,
#   'instrumentalness': 0.819,
#   'liveness': 0.0283,
#   'valence': 0.196,
#   'tempo': 127.984,
#   'type': 'audio_features',
#   'id': '5yN3wXc6fvM5SPTFjL6c4G',
#   'uri': 'spotify:track:5yN3wXc6fvM5SPTFjL6c4G',
#   'track_href': 'https://api.spotify.com/v1/tracks/5yN3wXc6fvM5SPTFjL6c4G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5yN3wXc6fvM5SPTFjL6c4G',
#   'duration_ms': 210000,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.583,
#   'key': 11,
#   'loudness': -9.111,
#   'mode': 1,
#   'speechiness': 0.072,
#   'acousticness': 0.108,
#   'instrumentalness': 0.731,
#   'liveness': 0.124,
#   'valence': 0.326,
#   'tempo': 123.975,
#   'type': 'audio_features',
#   'id': '6Lmx1AyfNlmOVCW2Sxisnk',
#   'uri': 'spotify:track:6Lmx1AyfNlmOVCW2Sxisnk',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Lmx1AyfNlmOVCW2Sxisnk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Lmx1AyfNlmOVCW2Sxisnk',
#   'duration_ms': 158710,
#   'time_signature': 4},
#  {'danceability': 0.862,
#   'energy': 0.79,
#   'key': 4,
#   'loudness': -8.412,
#   'mode': 0,
#   'speechiness': 0.0672,
#   'acousticness': 0.0418,
#   'instrumentalness': 0.00615,
#   'liveness': 0.0746,
#   'valence': 0.587,
#   'tempo': 129.005,
#   'type': 'audio_features',
#   'id': '3BbD2sqk7P7Rc9V0KF9o4s',
#   'uri': 'spotify:track:3BbD2sqk7P7Rc9V0KF9o4s',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BbD2sqk7P7Rc9V0KF9o4s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BbD2sqk7P7Rc9V0KF9o4s',
#   'duration_ms': 186125,
#   'time_signature': 4},
#  {'danceability': 0.544,
#   'energy': 0.856,
#   'key': 5,
#   'loudness': -6.84,
#   'mode': 0,
#   'speechiness': 0.0314,
#   'acousticness': 0.00162,
#   'instrumentalness': 0.818,
#   'liveness': 0.0763,
#   'valence': 0.233,
#   'tempo': 125.992,
#   'type': 'audio_features',
#   'id': '4G4patpYxsF6ovHZOX9wgR',
#   'uri': 'spotify:track:4G4patpYxsF6ovHZOX9wgR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4G4patpYxsF6ovHZOX9wgR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4G4patpYxsF6ovHZOX9wgR',
#   'duration_ms': 219048,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.662,
#   'key': 5,
#   'loudness': -6.771,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.0479,
#   'instrumentalness': 0.441,
#   'liveness': 0.103,
#   'valence': 0.67,
#   'tempo': 126.953,
#   'type': 'audio_features',
#   'id': '1xFrwpp4li4MFpMr9KpTEK',
#   'uri': 'spotify:track:1xFrwpp4li4MFpMr9KpTEK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xFrwpp4li4MFpMr9KpTEK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xFrwpp4li4MFpMr9KpTEK',
#   'duration_ms': 147402,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.77,
#   'key': 11,
#   'loudness': -6.641,
#   'mode': 0,
#   'speechiness': 0.0512,
#   'acousticness': 0.0988,
#   'instrumentalness': 0.896,
#   'liveness': 0.379,
#   'valence': 0.527,
#   'tempo': 126.006,
#   'type': 'audio_features',
#   'id': '7dDLAQ1y0qOq3E4DhNh8FS',
#   'uri': 'spotify:track:7dDLAQ1y0qOq3E4DhNh8FS',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dDLAQ1y0qOq3E4DhNh8FS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dDLAQ1y0qOq3E4DhNh8FS',
#   'duration_ms': 186727,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.845,
#   'key': 7,
#   'loudness': -5.057,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.031,
#   'instrumentalness': 0.719,
#   'liveness': 0.147,
#   'valence': 0.281,
#   'tempo': 124.994,
#   'type': 'audio_features',
#   'id': '7k0kq03bs3micRAVvYgzg8',
#   'uri': 'spotify:track:7k0kq03bs3micRAVvYgzg8',
#   'track_href': 'https://api.spotify.com/v1/tracks/7k0kq03bs3micRAVvYgzg8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7k0kq03bs3micRAVvYgzg8',
#   'duration_ms': 175200,
#   'time_signature': 4},
#  {'danceability': 0.782,
#   'energy': 0.882,
#   'key': 10,
#   'loudness': -3.718,
#   'mode': 0,
#   'speechiness': 0.0722,
#   'acousticness': 0.117,
#   'instrumentalness': 0.655,
#   'liveness': 0.261,
#   'valence': 0.729,
#   'tempo': 127.989,
#   'type': 'audio_features',
#   'id': '522LFdtOuvHkNQeYJrAvIC',
#   'uri': 'spotify:track:522LFdtOuvHkNQeYJrAvIC',
#   'track_href': 'https://api.spotify.com/v1/tracks/522LFdtOuvHkNQeYJrAvIC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/522LFdtOuvHkNQeYJrAvIC',
#   'duration_ms': 170156,
#   'time_signature': 4},
#  {'danceability': 0.864,
#   'energy': 0.452,
#   'key': 2,
#   'loudness': -7.896,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.0031,
#   'instrumentalness': 0.293,
#   'liveness': 0.111,
#   'valence': 0.223,
#   'tempo': 127.002,
#   'type': 'audio_features',
#   'id': '6IqVq76K6UuJdYwZFgXosQ',
#   'uri': 'spotify:track:6IqVq76K6UuJdYwZFgXosQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6IqVq76K6UuJdYwZFgXosQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6IqVq76K6UuJdYwZFgXosQ',
#   'duration_ms': 202205,
#   'time_signature': 4},
#  {'danceability': 0.888,
#   'energy': 0.948,
#   'key': 0,
#   'loudness': -5.658,
#   'mode': 1,
#   'speechiness': 0.189,
#   'acousticness': 0.068,
#   'instrumentalness': 0.00357,
#   'liveness': 0.24,
#   'valence': 0.51,
#   'tempo': 127.001,
#   'type': 'audio_features',
#   'id': '05IOuexttkZG6eQLFi3v40',
#   'uri': 'spotify:track:05IOuexttkZG6eQLFi3v40',
#   'track_href': 'https://api.spotify.com/v1/tracks/05IOuexttkZG6eQLFi3v40',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05IOuexttkZG6eQLFi3v40',
#   'duration_ms': 188916,
#   'time_signature': 4},
#  {'danceability': 0.785,
#   'energy': 0.903,
#   'key': 0,
#   'loudness': -4.715,
#   'mode': 1,
#   'speechiness': 0.0709,
#   'acousticness': 0.014,
#   'instrumentalness': 8.96e-05,
#   'liveness': 0.174,
#   'valence': 0.728,
#   'tempo': 123.999,
#   'type': 'audio_features',
#   'id': '1JM6JF5IUWmggaC1rYDAiH',
#   'uri': 'spotify:track:1JM6JF5IUWmggaC1rYDAiH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1JM6JF5IUWmggaC1rYDAiH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1JM6JF5IUWmggaC1rYDAiH',
#   'duration_ms': 135657,
#   'time_signature': 4},
#  {'danceability': 0.416,
#   'energy': 0.821,
#   'key': 10,
#   'loudness': -7.502,
#   'mode': 0,
#   'speechiness': 0.0394,
#   'acousticness': 0.183,
#   'instrumentalness': 0.013,
#   'liveness': 0.149,
#   'valence': 0.521,
#   'tempo': 122.916,
#   'type': 'audio_features',
#   'id': '7q887Wj7xbhsSKhHct5xKM',
#   'uri': 'spotify:track:7q887Wj7xbhsSKhHct5xKM',
#   'track_href': 'https://api.spotify.com/v1/tracks/7q887Wj7xbhsSKhHct5xKM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7q887Wj7xbhsSKhHct5xKM',
#   'duration_ms': 195122,
#   'time_signature': 4},
#  {'danceability': 0.887,
#   'energy': 0.863,
#   'key': 2,
#   'loudness': -4.2,
#   'mode': 1,
#   'speechiness': 0.0697,
#   'acousticness': 0.0176,
#   'instrumentalness': 0.0594,
#   'liveness': 0.288,
#   'valence': 0.517,
#   'tempo': 120.028,
#   'type': 'audio_features',
#   'id': '1afXT2ntjBUlydAFZ3db66',
#   'uri': 'spotify:track:1afXT2ntjBUlydAFZ3db66',
#   'track_href': 'https://api.spotify.com/v1/tracks/1afXT2ntjBUlydAFZ3db66',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1afXT2ntjBUlydAFZ3db66',
#   'duration_ms': 139436,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.966,
#   'key': 6,
#   'loudness': -3.745,
#   'mode': 1,
#   'speechiness': 0.106,
#   'acousticness': 0.00109,
#   'instrumentalness': 0.838,
#   'liveness': 0.415,
#   'valence': 0.193,
#   'tempo': 132.035,
#   'type': 'audio_features',
#   'id': '651YhrvzeVfOa8yIifIhUM',
#   'uri': 'spotify:track:651YhrvzeVfOa8yIifIhUM',
#   'track_href': 'https://api.spotify.com/v1/tracks/651YhrvzeVfOa8yIifIhUM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/651YhrvzeVfOa8yIifIhUM',
#   'duration_ms': 225682,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.971,
#   'key': 7,
#   'loudness': -4.732,
#   'mode': 1,
#   'speechiness': 0.0606,
#   'acousticness': 0.219,
#   'instrumentalness': 0.813,
#   'liveness': 0.0852,
#   'valence': 0.141,
#   'tempo': 128.037,
#   'type': 'audio_features',
#   'id': '5czwOsSExLRO25zcnaJuRr',
#   'uri': 'spotify:track:5czwOsSExLRO25zcnaJuRr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5czwOsSExLRO25zcnaJuRr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5czwOsSExLRO25zcnaJuRr',
#   'duration_ms': 156094,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.911,
#   'key': 10,
#   'loudness': -5.414,
#   'mode': 0,
#   'speechiness': 0.056,
#   'acousticness': 0.0137,
#   'instrumentalness': 0.65,
#   'liveness': 0.163,
#   'valence': 0.545,
#   'tempo': 123.996,
#   'type': 'audio_features',
#   'id': '2k9kWgFLCiAeRBTmwlGbAv',
#   'uri': 'spotify:track:2k9kWgFLCiAeRBTmwlGbAv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2k9kWgFLCiAeRBTmwlGbAv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2k9kWgFLCiAeRBTmwlGbAv',
#   'duration_ms': 166598,
#   'time_signature': 4},
#  {'danceability': 0.657,
#   'energy': 0.714,
#   'key': 5,
#   'loudness': -6.067,
#   'mode': 1,
#   'speechiness': 0.131,
#   'acousticness': 0.0296,
#   'instrumentalness': 0.0177,
#   'liveness': 0.259,
#   'valence': 0.225,
#   'tempo': 128.026,
#   'type': 'audio_features',
#   'id': '7yyYtLNqpXY8zY3TQbc9AK',
#   'uri': 'spotify:track:7yyYtLNqpXY8zY3TQbc9AK',
#   'track_href': 'https://api.spotify.com/v1/tracks/7yyYtLNqpXY8zY3TQbc9AK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7yyYtLNqpXY8zY3TQbc9AK',
#   'duration_ms': 184888,
#   'time_signature': 4},
#  {'danceability': 0.892,
#   'energy': 0.943,
#   'key': 1,
#   'loudness': -3.884,
#   'mode': 1,
#   'speechiness': 0.108,
#   'acousticness': 0.012,
#   'instrumentalness': 0.572,
#   'liveness': 0.208,
#   'valence': 0.254,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '6KCmJ8VI6VYNRNubSqi0Ck',
#   'uri': 'spotify:track:6KCmJ8VI6VYNRNubSqi0Ck',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KCmJ8VI6VYNRNubSqi0Ck',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KCmJ8VI6VYNRNubSqi0Ck',
#   'duration_ms': 205430,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.855,
#   'key': 5,
#   'loudness': -5.577,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.000807,
#   'instrumentalness': 4.9e-06,
#   'liveness': 0.345,
#   'valence': 0.917,
#   'tempo': 125.975,
#   'type': 'audio_features',
#   'id': '16Y0MeVVRU0SwpKDN9durD',
#   'uri': 'spotify:track:16Y0MeVVRU0SwpKDN9durD',
#   'track_href': 'https://api.spotify.com/v1/tracks/16Y0MeVVRU0SwpKDN9durD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16Y0MeVVRU0SwpKDN9durD',
#   'duration_ms': 126667,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.831,
#   'key': 6,
#   'loudness': -7.566,
#   'mode': 0,
#   'speechiness': 0.364,
#   'acousticness': 0.211,
#   'instrumentalness': 0.0037,
#   'liveness': 0.433,
#   'valence': 0.37,
#   'tempo': 136.327,
#   'type': 'audio_features',
#   'id': '5OtRUowagv3aSAcjekQmDm',
#   'uri': 'spotify:track:5OtRUowagv3aSAcjekQmDm',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OtRUowagv3aSAcjekQmDm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OtRUowagv3aSAcjekQmDm',
#   'duration_ms': 173785,
#   'time_signature': 4},
#  {'danceability': 0.833,
#   'energy': 0.848,
#   'key': 2,
#   'loudness': -6.104,
#   'mode': 1,
#   'speechiness': 0.268,
#   'acousticness': 0.0193,
#   'instrumentalness': 0.299,
#   'liveness': 0.11,
#   'valence': 0.249,
#   'tempo': 130.047,
#   'type': 'audio_features',
#   'id': '7eHBDsqfqOMyzMhtnhytNB',
#   'uri': 'spotify:track:7eHBDsqfqOMyzMhtnhytNB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7eHBDsqfqOMyzMhtnhytNB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eHBDsqfqOMyzMhtnhytNB',
#   'duration_ms': 154177,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.945,
#   'key': 1,
#   'loudness': -6.162,
#   'mode': 1,
#   'speechiness': 0.0731,
#   'acousticness': 0.000137,
#   'instrumentalness': 0.868,
#   'liveness': 0.326,
#   'valence': 0.0936,
#   'tempo': 132.053,
#   'type': 'audio_features',
#   'id': '58gWWPOLa3qYsWX2Hl1KRk',
#   'uri': 'spotify:track:58gWWPOLa3qYsWX2Hl1KRk',
#   'track_href': 'https://api.spotify.com/v1/tracks/58gWWPOLa3qYsWX2Hl1KRk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/58gWWPOLa3qYsWX2Hl1KRk',
#   'duration_ms': 185455,
#   'time_signature': 4},
#  {'danceability': 0.775,
#   'energy': 0.713,
#   'key': 9,
#   'loudness': -5.422,
#   'mode': 0,
#   'speechiness': 0.3,
#   'acousticness': 0.105,
#   'instrumentalness': 0.325,
#   'liveness': 0.0918,
#   'valence': 0.299,
#   'tempo': 125.934,
#   'type': 'audio_features',
#   'id': '2v0d2zo4bgHkge4B1O6e3c',
#   'uri': 'spotify:track:2v0d2zo4bgHkge4B1O6e3c',
#   'track_href': 'https://api.spotify.com/v1/tracks/2v0d2zo4bgHkge4B1O6e3c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2v0d2zo4bgHkge4B1O6e3c',
#   'duration_ms': 158571,
#   'time_signature': 4},
#  {'danceability': 0.793,
#   'energy': 0.907,
#   'key': 11,
#   'loudness': -4.448,
#   'mode': 0,
#   'speechiness': 0.12,
#   'acousticness': 0.0474,
#   'instrumentalness': 0.00604,
#   'liveness': 0.63,
#   'valence': 0.116,
#   'tempo': 126.016,
#   'type': 'audio_features',
#   'id': '7nrPXddIkx8hxM9Ot46JRX',
#   'uri': 'spotify:track:7nrPXddIkx8hxM9Ot46JRX',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nrPXddIkx8hxM9Ot46JRX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nrPXddIkx8hxM9Ot46JRX',
#   'duration_ms': 161000,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.909,
#   'key': 1,
#   'loudness': -5.435,
#   'mode': 0,
#   'speechiness': 0.041,
#   'acousticness': 0.0129,
#   'instrumentalness': 0.151,
#   'liveness': 0.135,
#   'valence': 0.384,
#   'tempo': 126.051,
#   'type': 'audio_features',
#   'id': '10E3RZH3FcO3bC8w7BHDwp',
#   'uri': 'spotify:track:10E3RZH3FcO3bC8w7BHDwp',
#   'track_href': 'https://api.spotify.com/v1/tracks/10E3RZH3FcO3bC8w7BHDwp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10E3RZH3FcO3bC8w7BHDwp',
#   'duration_ms': 202738,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.994,
#   'key': 1,
#   'loudness': -6.329,
#   'mode': 1,
#   'speechiness': 0.071,
#   'acousticness': 0.00158,
#   'instrumentalness': 0.875,
#   'liveness': 0.0673,
#   'valence': 0.732,
#   'tempo': 127.011,
#   'type': 'audio_features',
#   'id': '4C39WSjsA70cyKCwGsxH8v',
#   'uri': 'spotify:track:4C39WSjsA70cyKCwGsxH8v',
#   'track_href': 'https://api.spotify.com/v1/tracks/4C39WSjsA70cyKCwGsxH8v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4C39WSjsA70cyKCwGsxH8v',
#   'duration_ms': 197978,
#   'time_signature': 4},
#  {'danceability': 0.779,
#   'energy': 0.922,
#   'key': 0,
#   'loudness': -3.435,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.00394,
#   'instrumentalness': 0.78,
#   'liveness': 0.0711,
#   'valence': 0.533,
#   'tempo': 130.007,
#   'type': 'audio_features',
#   'id': '0qtjn6dbQ8VDNJwJQ9w7Cy',
#   'uri': 'spotify:track:0qtjn6dbQ8VDNJwJQ9w7Cy',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qtjn6dbQ8VDNJwJQ9w7Cy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qtjn6dbQ8VDNJwJQ9w7Cy',
#   'duration_ms': 133885,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.935,
#   'key': 11,
#   'loudness': -6.263,
#   'mode': 1,
#   'speechiness': 0.203,
#   'acousticness': 0.0742,
#   'instrumentalness': 0.0352,
#   'liveness': 0.081,
#   'valence': 0.31,
#   'tempo': 126.022,
#   'type': 'audio_features',
#   'id': '0lwyzp7GppQxv0Eu6wRkUo',
#   'uri': 'spotify:track:0lwyzp7GppQxv0Eu6wRkUo',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lwyzp7GppQxv0Eu6wRkUo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lwyzp7GppQxv0Eu6wRkUo',
#   'duration_ms': 155677,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.93,
#   'key': 5,
#   'loudness': -4.646,
#   'mode': 0,
#   'speechiness': 0.0768,
#   'acousticness': 0.0024,
#   'instrumentalness': 0.535,
#   'liveness': 0.4,
#   'valence': 0.431,
#   'tempo': 126.015,
#   'type': 'audio_features',
#   'id': '4MyPLcBTpqfXZJKcUhMXOg',
#   'uri': 'spotify:track:4MyPLcBTpqfXZJKcUhMXOg',
#   'track_href': 'https://api.spotify.com/v1/tracks/4MyPLcBTpqfXZJKcUhMXOg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MyPLcBTpqfXZJKcUhMXOg',
#   'duration_ms': 169524,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.895,
#   'key': 7,
#   'loudness': -5.059,
#   'mode': 1,
#   'speechiness': 0.215,
#   'acousticness': 0.011,
#   'instrumentalness': 0.0064,
#   'liveness': 0.379,
#   'valence': 0.566,
#   'tempo': 125.068,
#   'type': 'audio_features',
#   'id': '3w5TmfiZNSmOuebOgvGINc',
#   'uri': 'spotify:track:3w5TmfiZNSmOuebOgvGINc',
#   'track_href': 'https://api.spotify.com/v1/tracks/3w5TmfiZNSmOuebOgvGINc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3w5TmfiZNSmOuebOgvGINc',
#   'duration_ms': 146408,
#   'time_signature': 4},
#  {'danceability': 0.776,
#   'energy': 0.832,
#   'key': 8,
#   'loudness': -7.591,
#   'mode': 1,
#   'speechiness': 0.0489,
#   'acousticness': 0.0591,
#   'instrumentalness': 0.888,
#   'liveness': 0.121,
#   'valence': 0.293,
#   'tempo': 124.996,
#   'type': 'audio_features',
#   'id': '5ECWJFKkqePRH2SSlv8Ltq',
#   'uri': 'spotify:track:5ECWJFKkqePRH2SSlv8Ltq',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ECWJFKkqePRH2SSlv8Ltq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ECWJFKkqePRH2SSlv8Ltq',
#   'duration_ms': 219402,
#   'time_signature': 4},
#  {'danceability': 0.838,
#   'energy': 0.803,
#   'key': 6,
#   'loudness': -5.583,
#   'mode': 0,
#   'speechiness': 0.0713,
#   'acousticness': 0.00117,
#   'instrumentalness': 0.152,
#   'liveness': 0.04,
#   'valence': 0.577,
#   'tempo': 126.026,
#   'type': 'audio_features',
#   'id': '3VQWkf0zg6397V3ql6mwMq',
#   'uri': 'spotify:track:3VQWkf0zg6397V3ql6mwMq',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VQWkf0zg6397V3ql6mwMq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VQWkf0zg6397V3ql6mwMq',
#   'duration_ms': 148539,
#   'time_signature': 4},
#  {'danceability': 0.682,
#   'energy': 0.922,
#   'key': 7,
#   'loudness': -2.936,
#   'mode': 0,
#   'speechiness': 0.0421,
#   'acousticness': 0.00956,
#   'instrumentalness': 0.00215,
#   'liveness': 0.0626,
#   'valence': 0.266,
#   'tempo': 125.004,
#   'type': 'audio_features',
#   'id': '6NNpXXkpPDZKxdavZbVhwJ',
#   'uri': 'spotify:track:6NNpXXkpPDZKxdavZbVhwJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NNpXXkpPDZKxdavZbVhwJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NNpXXkpPDZKxdavZbVhwJ',
#   'duration_ms': 206160,
#   'time_signature': 4},
#  {'danceability': 0.565,
#   'energy': 0.743,
#   'key': 3,
#   'loudness': -7.738,
#   'mode': 0,
#   'speechiness': 0.0877,
#   'acousticness': 0.000926,
#   'instrumentalness': 0.177,
#   'liveness': 0.0491,
#   'valence': 0.118,
#   'tempo': 137.98,
#   'type': 'audio_features',
#   'id': '2meQ2wSIBU8OQDKlJcJk5j',
#   'uri': 'spotify:track:2meQ2wSIBU8OQDKlJcJk5j',
#   'track_href': 'https://api.spotify.com/v1/tracks/2meQ2wSIBU8OQDKlJcJk5j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2meQ2wSIBU8OQDKlJcJk5j',
#   'duration_ms': 205217,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.907,
#   'key': 1,
#   'loudness': -3.614,
#   'mode': 1,
#   'speechiness': 0.3,
#   'acousticness': 0.00373,
#   'instrumentalness': 5.28e-06,
#   'liveness': 0.0906,
#   'valence': 0.219,
#   'tempo': 132.046,
#   'type': 'audio_features',
#   'id': '7AxA87dIJ1FF4l1BQ98ZCZ',
#   'uri': 'spotify:track:7AxA87dIJ1FF4l1BQ98ZCZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7AxA87dIJ1FF4l1BQ98ZCZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7AxA87dIJ1FF4l1BQ98ZCZ',
#   'duration_ms': 141171,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.811,
#   'key': 0,
#   'loudness': -6.829,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.00473,
#   'instrumentalness': 0.0354,
#   'liveness': 0.644,
#   'valence': 0.399,
#   'tempo': 124.997,
#   'type': 'audio_features',
#   'id': '3hp1sx2wqHipS9fanoPrzV',
#   'uri': 'spotify:track:3hp1sx2wqHipS9fanoPrzV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3hp1sx2wqHipS9fanoPrzV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3hp1sx2wqHipS9fanoPrzV',
#   'duration_ms': 158463,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.894,
#   'key': 7,
#   'loudness': -5.31,
#   'mode': 1,
#   'speechiness': 0.0331,
#   'acousticness': 0.000142,
#   'instrumentalness': 0.675,
#   'liveness': 0.223,
#   'valence': 0.945,
#   'tempo': 134.963,
#   'type': 'audio_features',
#   'id': '5OJQ7sgz7ZEb9Mxsfqlpiv',
#   'uri': 'spotify:track:5OJQ7sgz7ZEb9Mxsfqlpiv',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OJQ7sgz7ZEb9Mxsfqlpiv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OJQ7sgz7ZEb9Mxsfqlpiv',
#   'duration_ms': 231135,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.941,
#   'key': 1,
#   'loudness': -6.211,
#   'mode': 1,
#   'speechiness': 0.14,
#   'acousticness': 0.024,
#   'instrumentalness': 0.527,
#   'liveness': 0.123,
#   'valence': 0.0741,
#   'tempo': 128.171,
#   'type': 'audio_features',
#   'id': '4fr0TUNlNMjORHGnZX9DQs',
#   'uri': 'spotify:track:4fr0TUNlNMjORHGnZX9DQs',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fr0TUNlNMjORHGnZX9DQs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fr0TUNlNMjORHGnZX9DQs',
#   'duration_ms': 120000,
#   'time_signature': 4},
#  {'danceability': 0.314,
#   'energy': 0.858,
#   'key': 11,
#   'loudness': -8.596,
#   'mode': 0,
#   'speechiness': 0.0563,
#   'acousticness': 0.00356,
#   'instrumentalness': 0.873,
#   'liveness': 0.145,
#   'valence': 0.0729,
#   'tempo': 127.046,
#   'type': 'audio_features',
#   'id': '26RfGZj3z5Y25w6tQDcAyM',
#   'uri': 'spotify:track:26RfGZj3z5Y25w6tQDcAyM',
#   'track_href': 'https://api.spotify.com/v1/tracks/26RfGZj3z5Y25w6tQDcAyM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/26RfGZj3z5Y25w6tQDcAyM',
#   'duration_ms': 306166,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.946,
#   'key': 1,
#   'loudness': -6.361,
#   'mode': 1,
#   'speechiness': 0.074,
#   'acousticness': 0.00193,
#   'instrumentalness': 0.463,
#   'liveness': 0.384,
#   'valence': 0.0792,
#   'tempo': 125.991,
#   'type': 'audio_features',
#   'id': '61JaHYd8nsdvB3srjgGZtM',
#   'uri': 'spotify:track:61JaHYd8nsdvB3srjgGZtM',
#   'track_href': 'https://api.spotify.com/v1/tracks/61JaHYd8nsdvB3srjgGZtM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61JaHYd8nsdvB3srjgGZtM',
#   'duration_ms': 152500,
#   'time_signature': 4},
#  {'danceability': 0.892,
#   'energy': 0.841,
#   'key': 11,
#   'loudness': -1.206,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.0127,
#   'instrumentalness': 0.654,
#   'liveness': 0.0877,
#   'valence': 0.597,
#   'tempo': 130.056,
#   'type': 'audio_features',
#   'id': '45lGbfYeIdseB3N8FSR9HG',
#   'uri': 'spotify:track:45lGbfYeIdseB3N8FSR9HG',
#   'track_href': 'https://api.spotify.com/v1/tracks/45lGbfYeIdseB3N8FSR9HG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45lGbfYeIdseB3N8FSR9HG',
#   'duration_ms': 136846,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.873,
#   'key': 8,
#   'loudness': -3.937,
#   'mode': 0,
#   'speechiness': 0.0498,
#   'acousticness': 0.0208,
#   'instrumentalness': 9.83e-05,
#   'liveness': 0.0689,
#   'valence': 0.143,
#   'tempo': 125.966,
#   'type': 'audio_features',
#   'id': '1clNueVAJ6a3orfLksJ1Sk',
#   'uri': 'spotify:track:1clNueVAJ6a3orfLksJ1Sk',
#   'track_href': 'https://api.spotify.com/v1/tracks/1clNueVAJ6a3orfLksJ1Sk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1clNueVAJ6a3orfLksJ1Sk',
#   'duration_ms': 196135,
#   'time_signature': 4},
#  {'danceability': 0.648,
#   'energy': 0.804,
#   'key': 9,
#   'loudness': -8.232,
#   'mode': 0,
#   'speechiness': 0.0541,
#   'acousticness': 0.00567,
#   'instrumentalness': 0.0033,
#   'liveness': 0.643,
#   'valence': 0.376,
#   'tempo': 123.971,
#   'type': 'audio_features',
#   'id': '5QH3sjtAIJmeUiVuwDOjui',
#   'uri': 'spotify:track:5QH3sjtAIJmeUiVuwDOjui',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QH3sjtAIJmeUiVuwDOjui',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QH3sjtAIJmeUiVuwDOjui',
#   'duration_ms': 189677,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.85,
#   'key': 10,
#   'loudness': -4.149,
#   'mode': 0,
#   'speechiness': 0.0662,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.000197,
#   'liveness': 0.0549,
#   'valence': 0.224,
#   'tempo': 123.01,
#   'type': 'audio_features',
#   'id': '4M3FhuDyw0IkedyN4oFvzj',
#   'uri': 'spotify:track:4M3FhuDyw0IkedyN4oFvzj',
#   'track_href': 'https://api.spotify.com/v1/tracks/4M3FhuDyw0IkedyN4oFvzj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4M3FhuDyw0IkedyN4oFvzj',
#   'duration_ms': 167805,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.96,
#   'key': 4,
#   'loudness': -3.436,
#   'mode': 0,
#   'speechiness': 0.166,
#   'acousticness': 0.00695,
#   'instrumentalness': 0.436,
#   'liveness': 0.537,
#   'valence': 0.103,
#   'tempo': 130.046,
#   'type': 'audio_features',
#   'id': '0UVBULfbKPCgJc779Zun1M',
#   'uri': 'spotify:track:0UVBULfbKPCgJc779Zun1M',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UVBULfbKPCgJc779Zun1M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UVBULfbKPCgJc779Zun1M',
#   'duration_ms': 169856,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.933,
#   'key': 9,
#   'loudness': -4.962,
#   'mode': 1,
#   'speechiness': 0.0544,
#   'acousticness': 0.0544,
#   'instrumentalness': 0.882,
#   'liveness': 0.0872,
#   'valence': 0.335,
#   'tempo': 124.998,
#   'type': 'audio_features',
#   'id': '6a7Vnxz6aezPxdKPTF72Yb',
#   'uri': 'spotify:track:6a7Vnxz6aezPxdKPTF72Yb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6a7Vnxz6aezPxdKPTF72Yb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6a7Vnxz6aezPxdKPTF72Yb',
#   'duration_ms': 202560,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.83,
#   'key': 9,
#   'loudness': -6.656,
#   'mode': 0,
#   'speechiness': 0.0535,
#   'acousticness': 0.0407,
#   'instrumentalness': 0.0121,
#   'liveness': 0.348,
#   'valence': 0.839,
#   'tempo': 125.979,
#   'type': 'audio_features',
#   'id': '4nTj9uSRpyhHWGaeZRUeqQ',
#   'uri': 'spotify:track:4nTj9uSRpyhHWGaeZRUeqQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nTj9uSRpyhHWGaeZRUeqQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nTj9uSRpyhHWGaeZRUeqQ',
#   'duration_ms': 166633,
#   'time_signature': 3},
#  {'danceability': 0.777,
#   'energy': 0.696,
#   'key': 10,
#   'loudness': -7.809,
#   'mode': 0,
#   'speechiness': 0.166,
#   'acousticness': 0.0209,
#   'instrumentalness': 0.598,
#   'liveness': 0.341,
#   'valence': 0.529,
#   'tempo': 129.026,
#   'type': 'audio_features',
#   'id': '6NOWq0oeufS8jQTv1zrZ0I',
#   'uri': 'spotify:track:6NOWq0oeufS8jQTv1zrZ0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NOWq0oeufS8jQTv1zrZ0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NOWq0oeufS8jQTv1zrZ0I',
#   'duration_ms': 281210,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.974,
#   'key': 6,
#   'loudness': -3.669,
#   'mode': 1,
#   'speechiness': 0.0524,
#   'acousticness': 0.000169,
#   'instrumentalness': 0.181,
#   'liveness': 0.141,
#   'valence': 0.347,
#   'tempo': 140.047,
#   'type': 'audio_features',
#   'id': '2xiNvyILhJ0mXpLVxOUhFh',
#   'uri': 'spotify:track:2xiNvyILhJ0mXpLVxOUhFh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2xiNvyILhJ0mXpLVxOUhFh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2xiNvyILhJ0mXpLVxOUhFh',
#   'duration_ms': 142714,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.906,
#   'key': 4,
#   'loudness': -5.047,
#   'mode': 1,
#   'speechiness': 0.298,
#   'acousticness': 0.0167,
#   'instrumentalness': 0.197,
#   'liveness': 0.264,
#   'valence': 0.171,
#   'tempo': 129.966,
#   'type': 'audio_features',
#   'id': '3ewziyfcz9bPtaqISZs67N',
#   'uri': 'spotify:track:3ewziyfcz9bPtaqISZs67N',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ewziyfcz9bPtaqISZs67N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ewziyfcz9bPtaqISZs67N',
#   'duration_ms': 176805,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.902,
#   'key': 6,
#   'loudness': -5.149,
#   'mode': 0,
#   'speechiness': 0.0384,
#   'acousticness': 0.0105,
#   'instrumentalness': 0.952,
#   'liveness': 0.0997,
#   'valence': 0.135,
#   'tempo': 128.021,
#   'type': 'audio_features',
#   'id': '7cmpWAZsamIlIiyU1aMGZD',
#   'uri': 'spotify:track:7cmpWAZsamIlIiyU1aMGZD',
#   'track_href': 'https://api.spotify.com/v1/tracks/7cmpWAZsamIlIiyU1aMGZD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7cmpWAZsamIlIiyU1aMGZD',
#   'duration_ms': 178594,
#   'time_signature': 4}]

# %%
import pandas as pd

dfclubbeats=pd.DataFrame(list_of_audio_features)    
dfclubbeats=dfclubbeats[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

dfclubbeats
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.847   0.690    -7.877       0.0493      0.012700
# 1          0.874   0.869    -5.996       0.0315      0.001160
# 2          0.848   0.821    -5.408       0.0527      0.016900
# 3          0.560   0.832    -6.432       0.0363      0.009530
# 4          0.683   0.932   -10.402       0.0513      0.038900
# ..           ...     ...       ...          ...           ...
# 70         0.701   0.830    -6.656       0.0535      0.040700
# 71         0.777   0.696    -7.809       0.1660      0.020900
# 72         0.529   0.974    -3.669       0.0524      0.000169
# 73         0.602   0.906    -5.047       0.2980      0.016700
# 74         0.627   0.902    -5.149       0.0384      0.010500
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000060    0.0526   0.6920  125.004  4zN21mbAuaD0WqtmaTZZeP
# 1           0.002380    0.1640   0.7260  126.027  5ZduaRci3iNUiDfJbBfAaf
# 2           0.000403    0.0962   0.2490  125.051  6GomT970rCOkKAyyrwJeZi
# 3           0.005410    0.5460   0.0818  126.000  4qDpLaFGf5ampf2DXD2TMA
# 4           0.605000    0.0615   0.5530  125.002  0w7JPlp7eEQI2EKW3ayXrv
# ..               ...       ...      ...      ...                     ...
# 70          0.012100    0.3480   0.8390  125.979  4nTj9uSRpyhHWGaeZRUeqQ
# 71          0.598000    0.3410   0.5290  129.026  6NOWq0oeufS8jQTv1zrZ0I
# 72          0.181000    0.1410   0.3470  140.047  2xiNvyILhJ0mXpLVxOUhFh
# 73          0.197000    0.2640   0.1710  129.966  3ewziyfcz9bPtaqISZs67N
# 74          0.952000    0.0997   0.1350  128.021  7cmpWAZsamIlIiyU1aMGZD
#
#     duration_ms
# 0        186662
# 1        102861
# 2        157445
# 3        236000
# 4        235786
# ..          ...
# 70       166633
# 71       281210
# 72       142714
# 73       176805
# 74       178594
#
# [75 rows x 11 columns]

# %%
dfglobal.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22264\4116659922.py in <module>
# ----> 1 dfglobal.head()
#
# NameError: name 'dfglobal' is not defined

# %%
dfgermany.head()

# %%
dfviral.head()

# %%
dfmexico.head()

# %%
dfgoldschool.head()

# %%
df90shiphop.head()

# %%
dfpophits.head()

# %%
dfrockclassic.head()

# %%
dfindiessential.head()

# %%
dfclubbeats.head()

# %%
result = pd.concat([dfglobal, dfgermany, dfviral, dfmexico, dfgoldschool, df90shiphop, dfpophits, dfrockclassic, dfindiessential, dfclubbeats], axis=0)
result

# %%
result.describe()
# Out:
#        danceability      energy    loudness  speechiness  acousticness  \
# count    575.000000  575.000000  575.000000   575.000000    575.000000
# mean       0.667235    0.680188   -6.762477     0.113717      0.198910
# std        0.155096    0.173103    2.625227     0.108870      0.225206
# min        0.174000    0.129000  -20.149000     0.023700      0.000005
# 25%        0.559000    0.559000   -8.007500     0.039100      0.027000
# 50%        0.681000    0.690000   -6.231000     0.059300      0.117000
# 75%        0.783000    0.810000   -5.107500     0.159000      0.304500
# max        0.954000    0.994000   -1.206000     0.579000      0.969000
#
#        instrumentalness    liveness     valence       tempo    duration_ms  \
# count        575.000000  575.000000  575.000000  575.000000     575.000000
# mean           0.086820    0.185660    0.529923  120.976174  211666.911304
# std            0.216595    0.139442    0.237247   28.769922   58154.089456
# min            0.000000    0.027100    0.038500   61.859000   97960.000000
# 25%            0.000000    0.093400    0.344500   96.147500  170169.000000
# 50%            0.000033    0.128000    0.533000  122.895000  202738.000000
# 75%            0.005430    0.248500    0.726000  138.683000  244160.000000
# max            0.952000    0.957000    0.973000  210.164000  535733.000000
#
#              key       mode  time_signature
# count  50.000000  50.000000       50.000000
# mean    6.540000   0.440000        3.980000
# std     3.965206   0.501427        0.141421
# min     0.000000   0.000000        3.000000
# 25%     2.500000   0.000000        4.000000
# 50%     7.000000   0.000000        4.000000
# 75%    10.000000   1.000000        4.000000
# max    11.000000   1.000000        4.000000

# %%
print(result1)
# Out:
# None

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score


scaler = StandardScaler()
scaler.fit(result1)
result1_scaled = scaler.transform(result1)
result1_scaled_df = pd.DataFrame(result1_scaled, columns = result1.columns)
display(result1.head())
print()
display(result1_scaled_df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3200\1733440879.py in <module>
#      10
#      11 scaler = StandardScaler()
# ---> 12 scaler.fit(result1)
#      13 result1_scaled = scaler.transform(result1)
#      14 result1_scaled_df = pd.DataFrame(result1_scaled, columns = result1.columns)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     759             # If input is scalar raise error
#     760             if array.ndim == 0:
# --> 761                 raise ValueError(
#     762                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#     763                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=nan.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
